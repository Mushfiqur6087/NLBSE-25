# %% [markdown]
# # Run in kaggle T4 * 2 gpu

# %%
# %pip install transformers
# %pip install datasets
# %pip install accelerate
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.45.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.25.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets) (3.15.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/conda/lib/python3.10/site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.22.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.25.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.22.0->datasets) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->datasets) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (0.34.2)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /opt/conda/lib/python3.10/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (2.4.0)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.4.5)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (2024.6.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->accelerate) (3.1.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings("ignore")
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline, AutoModel
import torch
from datasets import load_dataset
import pandas as pd
from tqdm import tqdm
from accelerate import Accelerator

# %%
if torch.cuda.is_available():
    # Get the number of GPUs available
    num_gpus = torch.cuda.device_count()
    print(f"Number of GPUs available: {num_gpus}")
    
    # Print out the name of each GPU and memory details
    for i in range(num_gpus):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
        print(f"Total memory: {torch.cuda.get_device_properties(i).total_memory / 1e9} GB")
    
    # If multiple GPUs are available, use DataParallel for multi-GPU
    if num_gpus > 1:
        print("Using DataParallel for multi-GPU training.")
        # Example: Wrap your model with DataParallel
    else:
        print("Only one GPU available, using single GPU mode.")
else:
    print("No GPUs available, using CPU.")
    
def setup_translation_pipeline(source_lang, target_lang):
    """
    Set up a translation pipeline using a pretrained model from Helsinki-NLP, optimized for multi-GPU with Accelerate.

    Args:
        source_lang (str): The source language code (e.g., "en" for English).
        target_lang (str): The target language code (e.g., "fr" for French).

    Returns:
        transformers.Pipeline: A translation pipeline configured for the given language pair.
    """
    # Define the model name based on the source and target languages
    model_name = f"Helsinki-NLP/opus-mt-{source_lang}-{target_lang}"
    
    # Load the tokenizer for the specified model
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    
    # Load the translation model with memory optimization and half-precision support
    model = AutoModelForSeq2SeqLM.from_pretrained(
        model_name,
        return_dict=True,  # Use a dictionary for the model's output for easier access
        low_cpu_mem_usage=True,  # Optimize for low memory usage during model loading
        torch_dtype=torch.float16,  # Use half-precision for faster computation (requires supported GPU)
        trust_remote_code=True,  # Trust the model's remote configuration if specified
    )
    
    # Use the Accelerate library for better multi-GPU support
    accelerator = Accelerator()

    # Move the model to the appropriate device using Accelerator (handles multi-GPU)
    model = accelerator.prepare(model)

    # Set up and return the translation pipeline
    translation_pipeline = pipeline(
        "translation",  # Specify the task as translation
        model=model,  # Provide the loaded model
        tokenizer=tokenizer,  # Provide the loaded tokenizer
        torch_dtype=torch.float16,  # Use half-precision for the pipeline
        max_length=512,
        truncation=True,
        device=accelerator.device  # Use the device from Accelerator (handles multi-GPU)
    )

    return translation_pipeline
# Out:
# Number of GPUs available: 2
# GPU 0: Tesla T4
# Total memory: 15.828320256 GB
# GPU 1: Tesla T4
# Total memory: 15.828320256 GB
# Using DataParallel for multi-GPU training.

# %%
# Function to translate and retranslate for a given target language
def translate_retranslate(ds, source_lang, target_lang, batch_size=32):
    """
    Translate the dataset's 'comment_sentence' column to a target language and back to the source language.
    
    Args:
        ds (Dataset): Hugging Face dataset containing a 'comment_sentence' column.
        source_lang (str): Source language code (e.g., "en" for English).
        target_lang (str): Target language code to translate to and back.
        batch_size (int): Number of rows to process in a single batch.

    Returns:
        Dataset: Hugging Face dataset with a new column for retranslated texts.
    """
    # Set up translation pipelines
    pipe_to_target = setup_translation_pipeline(source_lang, target_lang)  # English to target language
    pipe_to_source = setup_translation_pipeline(target_lang, source_lang)  # Target language back to English

    retranslated_texts = []

    # Process the dataset in batches to optimize memory usage and speed
    for i in tqdm(range(0, len(ds), batch_size), desc=f"Translating to {target_lang} and back"):
        # Extract a batch of 'comment_sentence' without converting to pandas
        batch = ds[i: i + batch_size]["comment_sentence"]

        # Step 1: Translate from source language to target language
        target_translations = pipe_to_target(batch, max_length=512, do_sample=False)
        target_texts = [result["translation_text"] for result in target_translations]

        # Step 2: Translate back to the source language (English)
        english_translations = pipe_to_source(target_texts, max_length=512, do_sample=False)
        retranslated_batch = [result["translation_text"].strip() for result in english_translations]

        # Append the retranslated texts to the result list
        retranslated_texts.extend(retranslated_batch)
                # Clear CUDA cache to prevent memory overload
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    # Add the retranslated texts as a new column in the dataset
    ds = ds.add_column(f"retranslated_text_english_from_{target_lang}", retranslated_texts)
    return ds

# Load the dataset (e.g., the first 10 rows from the Python training split)
df = load_dataset("NLBSE/nlbse25-code-comment-classification", split="pharo_train")

# List of target languages to process for retranslation
languages = ["de", "fr", "zh", "hi", "es", "ru","ar","nl","it","ca","gl","grk","trk","uk","ur","vi","roa","sv"]

# Loop through each language and retranslate
for lang in tqdm(languages, desc="Processing languages"):
    df = translate_retranslate(df, "en", lang)
# Out:
# README.md:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# java_train-00000-of-00001.parquet:   0%|          | 0.00/680k [00:00<?, ?B/s]
# java_test-00000-of-00001.parquet:   0%|          | 0.00/174k [00:00<?, ?B/s]
# python_train-00000-of-00001.parquet:   0%|          | 0.00/126k [00:00<?, ?B/s]
# python_test-00000-of-00001.parquet:   0%|          | 0.00/35.7k [00:00<?, ?B/s]
# pharo_train-00000-of-00001.parquet:   0%|          | 0.00/113k [00:00<?, ?B/s]
# pharo_test-00000-of-00001.parquet:   0%|          | 0.00/30.6k [00:00<?, ?B/s]
# Generating java_train split:   0%|          | 0/7614 [00:00<?, ? examples/s]
# Generating java_test split:   0%|          | 0/1725 [00:00<?, ? examples/s]
# Generating python_train split:   0%|          | 0/1884 [00:00<?, ? examples/s]
# Generating python_test split:   0%|          | 0/406 [00:00<?, ? examples/s]
# Generating pharo_train split:   0%|          | 0/1298 [00:00<?, ? examples/s]
# Generating pharo_test split:   0%|          | 0/289 [00:00<?, ? examples/s]
# Processing languages:   0%|          | 0/18 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/768k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/797k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/298M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/797k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/768k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/298M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to de and back:   0%|          | 0/41 [00:00<?, ?it/s]
# Translating to de and back:   2%|▏         | 1/41 [00:11<07:28, 11.22s/it]
# Translating to de and back:   5%|▍         | 2/41 [00:21<06:51, 10.56s/it]
# Translating to de and back:   7%|▋         | 3/41 [00:33<07:04, 11.17s/it]
# Translating to de and back:  10%|▉         | 4/41 [00:47<07:34, 12.27s/it]
# Translating to de and back:  12%|█▏        | 5/41 [01:02<08:04, 13.46s/it]
# Translating to de and back:  15%|█▍        | 6/41 [01:14<07:31, 12.90s/it]
# Translating to de and back:  17%|█▋        | 7/41 [01:26<07:12, 12.71s/it]
# Translating to de and back:  20%|█▉        | 8/41 [01:37<06:39, 12.10s/it]
# Translating to de and back:  22%|██▏       | 9/41 [01:46<05:55, 11.12s/it]
# Translating to de and back:  24%|██▍       | 10/41 [02:02<06:32, 12.65s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#
# Translating to de and back:  27%|██▋       | 11/41 [02:17<06:41, 13.37s/it]
# Translating to de and back:  29%|██▉       | 12/41 [02:33<06:53, 14.25s/it]
# Translating to de and back:  32%|███▏      | 13/41 [02:49<06:45, 14.49s/it]
# Translating to de and back:  34%|███▍      | 14/41 [03:01<06:16, 13.96s/it]
# Translating to de and back:  37%|███▋      | 15/41 [03:12<05:37, 12.99s/it]
# Translating to de and back:  39%|███▉      | 16/41 [03:18<04:31, 10.85s/it]
# Translating to de and back:  41%|████▏     | 17/41 [03:26<04:01, 10.06s/it]
# Translating to de and back:  44%|████▍     | 18/41 [03:41<04:23, 11.45s/it]
# Translating to de and back:  46%|████▋     | 19/41 [03:50<03:58, 10.83s/it]
# Translating to de and back:  49%|████▉     | 20/41 [04:00<03:40, 10.50s/it]
# Translating to de and back:  51%|█████     | 21/41 [04:09<03:23, 10.19s/it]
# Translating to de and back:  54%|█████▎    | 22/41 [04:21<03:23, 10.69s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  56%|█████▌    | 23/41 [04:44<04:17, 14.28s/it]
# Translating to de and back:  59%|█████▊    | 24/41 [04:54<03:40, 12.98s/it]
# Translating to de and back:  61%|██████    | 25/41 [05:02<03:05, 11.62s/it]
# Translating to de and back:  63%|██████▎   | 26/41 [05:15<02:59, 11.94s/it]
# Translating to de and back:  66%|██████▌   | 27/41 [05:27<02:46, 11.88s/it]
# Translating to de and back:  68%|██████▊   | 28/41 [05:34<02:16, 10.48s/it]
# Translating to de and back:  71%|███████   | 29/41 [05:48<02:20, 11.69s/it]
# Translating to de and back:  73%|███████▎  | 30/41 [06:21<03:17, 17.92s/it]
# Translating to de and back:  76%|███████▌  | 31/41 [06:34<02:44, 16.45s/it]
# Translating to de and back:  78%|███████▊  | 32/41 [06:43<02:07, 14.20s/it]
# Translating to de and back:  80%|████████  | 33/41 [06:55<01:48, 13.58s/it]
# Translating to de and back:  83%|████████▎ | 34/41 [07:07<01:31, 13.09s/it]
# Translating to de and back:  85%|████████▌ | 35/41 [07:16<01:10, 11.78s/it]
# Translating to de and back:  88%|████████▊ | 36/41 [07:28<00:59, 11.87s/it]
# Translating to de and back:  90%|█████████ | 37/41 [07:41<00:48, 12.17s/it]
# Translating to de and back:  93%|█████████▎| 38/41 [07:49<00:33, 11.16s/it]
# Translating to de and back:  95%|█████████▌| 39/41 [08:00<00:21, 11.00s/it]
# Translating to de and back:  98%|█████████▊| 40/41 [08:12<00:11, 11.38s/it]
# Translating to de and back: 100%|██████████| 41/41 [08:17<00:00, 12.14s/it]
# Processing languages:   6%|▌         | 1/18 [08:32<2:25:20, 512.98s/it]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to fr and back:   0%|          | 0/41 [00:00<?, ?it/s]
# Translating to fr and back:   2%|▏         | 1/41 [00:10<06:46, 10.16s/it]
# Translating to fr and back:   5%|▍         | 2/41 [00:20<06:34, 10.10s/it]
# Translating to fr and back:   7%|▋         | 3/41 [00:32<06:55, 10.94s/it]
# Translating to fr and back:  10%|▉         | 4/41 [00:46<07:29, 12.14s/it]
# Translating to fr and back:  12%|█▏        | 5/41 [00:55<06:46, 11.29s/it]
# Translating to fr and back:  15%|█▍        | 6/41 [01:07<06:40, 11.45s/it]
# Translating to fr and back:  17%|█▋        | 7/41 [01:19<06:37, 11.70s/it]
# Translating to fr and back:  20%|█▉        | 8/41 [01:30<06:16, 11.39s/it]
# Translating to fr and back:  22%|██▏       | 9/41 [01:40<05:44, 10.76s/it]
# Translating to fr and back:  24%|██▍       | 10/41 [01:48<05:09,  9.97s/it]
# Translating to fr and back:  27%|██▋       | 11/41 [02:02<05:41, 11.37s/it]
# Translating to fr and back:  29%|██▉       | 12/41 [02:19<06:15, 12.96s/it]
# Translating to fr and back:  32%|███▏      | 13/41 [02:34<06:19, 13.54s/it]
# Translating to fr and back:  34%|███▍      | 14/41 [02:47<06:00, 13.34s/it]
# Translating to fr and back:  37%|███▋      | 15/41 [02:57<05:22, 12.39s/it]
# Translating to fr and back:  39%|███▉      | 16/41 [03:03<04:21, 10.44s/it]
# Translating to fr and back:  41%|████▏     | 17/41 [03:11<03:55,  9.81s/it]
# Translating to fr and back:  44%|████▍     | 18/41 [03:20<03:38,  9.48s/it]
# Translating to fr and back:  46%|████▋     | 19/41 [03:28<03:23,  9.25s/it]
# Translating to fr and back:  49%|████▉     | 20/41 [03:38<03:17,  9.41s/it]
# Translating to fr and back:  51%|█████     | 21/41 [03:48<03:09,  9.46s/it]
# Translating to fr and back:  54%|█████▎    | 22/41 [03:59<03:08,  9.94s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to fr and back:  56%|█████▌    | 23/41 [04:30<04:52, 16.25s/it]
# Translating to fr and back:  59%|█████▊    | 24/41 [04:39<04:00, 14.16s/it]
# Translating to fr and back:  61%|██████    | 25/41 [04:48<03:19, 12.50s/it]
# Translating to fr and back:  63%|██████▎   | 26/41 [04:57<02:52, 11.52s/it]
# Translating to fr and back:  66%|██████▌   | 27/41 [05:08<02:40, 11.48s/it]
# Translating to fr and back:  68%|██████▊   | 28/41 [05:17<02:17, 10.56s/it]
# Translating to fr and back:  71%|███████   | 29/41 [05:24<01:55,  9.59s/it]
# Translating to fr and back:  73%|███████▎  | 30/41 [05:32<01:39,  9.07s/it]
# Translating to fr and back:  76%|███████▌  | 31/41 [05:39<01:23,  8.40s/it]
# Translating to fr and back:  78%|███████▊  | 32/41 [05:44<01:06,  7.42s/it]
# Translating to fr and back:  80%|████████  | 33/41 [05:53<01:02,  7.78s/it]
# Translating to fr and back:  83%|████████▎ | 34/41 [06:01<00:55,  7.86s/it]
# Translating to fr and back:  85%|████████▌ | 35/41 [06:09<00:48,  8.00s/it]
# Translating to fr and back:  88%|████████▊ | 36/41 [06:22<00:46,  9.38s/it]
# Translating to fr and back:  90%|█████████ | 37/41 [06:30<00:36,  9.14s/it]
# Translating to fr and back:  93%|█████████▎| 38/41 [06:39<00:27,  9.06s/it]
# Translating to fr and back:  95%|█████████▌| 39/41 [06:50<00:19,  9.53s/it]
# Translating to fr and back:  98%|█████████▊| 40/41 [07:01<00:10, 10.23s/it]
# Translating to fr and back: 100%|██████████| 41/41 [07:06<00:00, 10.40s/it]
# Processing languages:  11%|█         | 2/18 [15:55<2:05:48, 471.77s/it]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/806k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/805k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.62M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/805k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/807k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.62M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to zh and back:   0%|          | 0/41 [00:00<?, ?it/s]
# Translating to zh and back:   2%|▏         | 1/41 [00:09<06:10,  9.25s/it]
# Translating to zh and back:   5%|▍         | 2/41 [00:19<06:23,  9.83s/it]
# Translating to zh and back:   7%|▋         | 3/41 [00:30<06:42, 10.59s/it]
# Translating to zh and back:  10%|▉         | 4/41 [00:45<07:22, 11.95s/it]
# Translating to zh and back:  12%|█▏        | 5/41 [00:54<06:43, 11.22s/it]
# Translating to zh and back:  15%|█▍        | 6/41 [01:07<06:44, 11.56s/it]
# Translating to zh and back:  17%|█▋        | 7/41 [01:23<07:29, 13.22s/it]
# Translating to zh and back:  20%|█▉        | 8/41 [01:35<07:05, 12.88s/it]
# Translating to zh and back:  22%|██▏       | 9/41 [01:45<06:17, 11.79s/it]
# Translating to zh and back:  24%|██▍       | 10/41 [01:54<05:44, 11.11s/it]Your input_length: 510 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to zh and back:  27%|██▋       | 11/41 [02:13<06:39, 13.32s/it]
# Translating to zh and back:  29%|██▉       | 12/41 [02:32<07:14, 14.99s/it]
# Translating to zh and back:  32%|███▏      | 13/41 [02:47<07:07, 15.27s/it]
# Translating to zh and back:  34%|███▍      | 14/41 [03:02<06:44, 14.99s/it]
# Translating to zh and back:  37%|███▋      | 15/41 [03:12<05:55, 13.67s/it]
# Translating to zh and back:  39%|███▉      | 16/41 [03:19<04:49, 11.58s/it]
# Translating to zh and back:  41%|████▏     | 17/41 [03:28<04:20, 10.84s/it]
# Translating to zh and back:  44%|████▍     | 18/41 [03:44<04:43, 12.34s/it]
# Translating to zh and back:  46%|████▋     | 19/41 [03:58<04:39, 12.68s/it]
# Translating to zh and back:  49%|████▉     | 20/41 [04:08<04:09, 11.86s/it]
# Translating to zh and back:  51%|█████     | 21/41 [04:18<03:50, 11.54s/it]
# Translating to zh and back:  54%|█████▎    | 22/41 [04:30<03:37, 11.44s/it]
# Translating to zh and back:  56%|█████▌    | 23/41 [04:40<03:20, 11.17s/it]
# Translating to zh and back:  59%|█████▊    | 24/41 [04:50<03:03, 10.80s/it]
# Translating to zh and back:  61%|██████    | 25/41 [04:58<02:39,  9.97s/it]
# Translating to zh and back:  63%|██████▎   | 26/41 [05:09<02:32, 10.15s/it]
# Translating to zh and back:  66%|██████▌   | 27/41 [05:21<02:30, 10.76s/it]
# Translating to zh and back:  68%|██████▊   | 28/41 [05:28<02:07,  9.84s/it]Your input_length: 507 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to zh and back:  71%|███████   | 29/41 [05:54<02:55, 14.62s/it]
# Translating to zh and back:  73%|███████▎  | 30/41 [06:09<02:40, 14.62s/it]
# Translating to zh and back:  76%|███████▌  | 31/41 [06:16<02:04, 12.41s/it]
# Translating to zh and back:  78%|███████▊  | 32/41 [06:23<01:35, 10.62s/it]Your input_length: 473 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 473 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to zh and back:  80%|████████  | 33/41 [06:49<02:02, 15.32s/it]Your input_length: 507 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to zh and back:  83%|████████▎ | 34/41 [07:11<02:00, 17.25s/it]
# Translating to zh and back:  85%|████████▌ | 35/41 [07:21<01:31, 15.31s/it]
# Translating to zh and back:  88%|████████▊ | 36/41 [07:31<01:07, 13.46s/it]
# Translating to zh and back:  90%|█████████ | 37/41 [07:44<00:53, 13.44s/it]
# Translating to zh and back:  93%|█████████▎| 38/41 [07:53<00:36, 12.13s/it]
# Translating to zh and back:  95%|█████████▌| 39/41 [08:04<00:23, 11.72s/it]
# Translating to zh and back:  98%|█████████▊| 40/41 [08:15<00:11, 11.70s/it]
# Translating to zh and back: 100%|██████████| 41/41 [08:23<00:00, 12.29s/it]
# Processing languages:  17%|█▋        | 3/18 [24:34<2:03:15, 493.03s/it]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/812k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/306M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/813k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.06M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/304M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to hi and back:   0%|          | 0/41 [00:00<?, ?it/s]
# Translating to hi and back:   2%|▏         | 1/41 [00:09<06:28,  9.72s/it]
# Translating to hi and back:   5%|▍         | 2/41 [00:19<06:14,  9.59s/it]
# Translating to hi and back:   7%|▋         | 3/41 [00:29<06:22, 10.06s/it]
# Translating to hi and back:  10%|▉         | 4/41 [00:43<06:59, 11.34s/it]
# Translating to hi and back:  12%|█▏        | 5/41 [00:52<06:19, 10.56s/it]
# Translating to hi and back:  15%|█▍        | 6/41 [01:02<06:05, 10.43s/it]
# Translating to hi and back:  17%|█▋        | 7/41 [01:13<05:59, 10.58s/it]
# Translating to hi and back:  20%|█▉        | 8/41 [01:23<05:39, 10.30s/it]
# Translating to hi and back:  22%|██▏       | 9/41 [01:31<05:06,  9.58s/it]
# Translating to hi and back:  24%|██▍       | 10/41 [01:38<04:38,  8.97s/it]
# Translating to hi and back:  27%|██▋       | 11/41 [01:53<05:20, 10.69s/it]
# Translating to hi and back:  29%|██▉       | 12/41 [02:09<06:00, 12.44s/it]Your input_length: 505 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to hi and back:  32%|███▏      | 13/41 [02:31<07:07, 15.29s/it]
# Translating to hi and back:  34%|███▍      | 14/41 [02:43<06:24, 14.25s/it]
# Translating to hi and back:  37%|███▋      | 15/41 [02:52<05:33, 12.84s/it]
# Translating to hi and back:  39%|███▉      | 16/41 [03:00<04:39, 11.16s/it]
# Translating to hi and back:  41%|████▏     | 17/41 [03:08<04:03, 10.15s/it]
# Translating to hi and back:  44%|████▍     | 18/41 [03:17<03:45,  9.82s/it]
# Translating to hi and back:  46%|████▋     | 19/41 [03:26<03:32,  9.66s/it]
# Translating to hi and back:  49%|████▉     | 20/41 [03:40<03:53, 11.10s/it]
# Translating to hi and back:  51%|█████     | 21/41 [03:49<03:27, 10.37s/it]
# Translating to hi and back:  54%|█████▎    | 22/41 [03:59<03:17, 10.39s/it]
# Translating to hi and back:  56%|█████▌    | 23/41 [04:06<02:46,  9.25s/it]
# Translating to hi and back:  59%|█████▊    | 24/41 [04:15<02:37,  9.26s/it]
# Translating to hi and back:  61%|██████    | 25/41 [04:23<02:22,  8.92s/it]
# Translating to hi and back:  63%|██████▎   | 26/41 [04:32<02:13,  8.91s/it]
# Translating to hi and back:  66%|██████▌   | 27/41 [04:43<02:11,  9.39s/it]
# Translating to hi and back:  68%|██████▊   | 28/41 [04:56<02:16, 10.51s/it]
# Translating to hi and back:  71%|███████   | 29/41 [05:03<01:54,  9.52s/it]
# Translating to hi and back:  73%|███████▎  | 30/41 [05:11<01:39,  9.02s/it]
# Translating to hi and back:  76%|███████▌  | 31/41 [05:18<01:23,  8.36s/it]
# Translating to hi and back:  78%|███████▊  | 32/41 [05:23<01:06,  7.43s/it]
# Translating to hi and back:  80%|████████  | 33/41 [05:31<00:59,  7.46s/it]
# Translating to hi and back:  83%|████████▎ | 34/41 [05:39<00:53,  7.63s/it]
# Translating to hi and back:  85%|████████▌ | 35/41 [05:47<00:47,  7.88s/it]
# Translating to hi and back:  88%|████████▊ | 36/41 [05:55<00:39,  7.95s/it]
# Translating to hi and back:  90%|█████████ | 37/41 [06:04<00:32,  8.13s/it]
# Translating to hi and back:  93%|█████████▎| 38/41 [06:12<00:24,  8.08s/it]
# Translating to hi and back:  95%|█████████▌| 39/41 [06:21<00:17,  8.55s/it]
# Translating to hi and back:  98%|█████████▊| 40/41 [06:32<00:09,  9.25s/it]
# Translating to hi and back: 100%|██████████| 41/41 [06:36<00:00,  9.68s/it]
# Processing languages:  22%|██▏       | 4/18 [31:25<1:47:30, 460.77s/it]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.47k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/826k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.44k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/826k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to es and back:   0%|          | 0/41 [00:00<?, ?it/s]
# Translating to es and back:   2%|▏         | 1/41 [00:09<06:33,  9.83s/it]
# Translating to es and back:   5%|▍         | 2/41 [00:25<08:44, 13.46s/it]
# Translating to es and back:   7%|▋         | 3/41 [00:37<08:00, 12.66s/it]
# Translating to es and back:  10%|▉         | 4/41 [00:51<08:02, 13.03s/it]
# Translating to es and back:  12%|█▏        | 5/41 [01:00<07:05, 11.82s/it]
# Translating to es and back:  15%|█▍        | 6/41 [01:12<06:52, 11.78s/it]
# Translating to es and back:  17%|█▋        | 7/41 [01:24<06:45, 11.93s/it]
# Translating to es and back:  20%|█▉        | 8/41 [01:35<06:26, 11.71s/it]
# Translating to es and back:  22%|██▏       | 9/41 [01:45<05:50, 10.94s/it]
# Translating to es and back:  24%|██▍       | 10/41 [01:52<05:08,  9.95s/it]
# Translating to es and back:  27%|██▋       | 11/41 [02:07<05:41, 11.40s/it]
# Translating to es and back:  29%|██▉       | 12/41 [02:24<06:19, 13.08s/it]
# Translating to es and back:  32%|███▏      | 13/41 [02:39<06:25, 13.77s/it]
# Translating to es and back:  34%|███▍      | 14/41 [02:52<06:02, 13.41s/it]
# Translating to es and back:  37%|███▋      | 15/41 [03:03<05:26, 12.55s/it]
# Translating to es and back:  39%|███▉      | 16/41 [03:09<04:24, 10.59s/it]
# Translating to es and back:  41%|████▏     | 17/41 [03:17<03:59,  9.96s/it]
# Translating to es and back:  44%|████▍     | 18/41 [03:26<03:43,  9.70s/it]
# Translating to es and back:  46%|████▋     | 19/41 [03:35<03:29,  9.51s/it]
# Translating to es and back:  49%|████▉     | 20/41 [03:52<04:04, 11.65s/it]
# Translating to es and back:  51%|█████     | 21/41 [04:02<03:41, 11.05s/it]
# Translating to es and back:  54%|█████▎    | 22/41 [04:13<03:33, 11.22s/it]
# Translating to es and back:  56%|█████▌    | 23/41 [04:24<03:18, 11.01s/it]
# Translating to es and back:  59%|█████▊    | 24/41 [04:33<02:59, 10.56s/it]
# Translating to es and back:  61%|██████    | 25/41 [04:41<02:36,  9.81s/it]
# Translating to es and back:  63%|██████▎   | 26/41 [04:51<02:27,  9.86s/it]
# Translating to es and back:  66%|██████▌   | 27/41 [05:02<02:23, 10.27s/it]
# Translating to es and back:  68%|██████▊   | 28/41 [05:10<02:02,  9.42s/it]
# Translating to es and back:  71%|███████   | 29/41 [05:18<01:46,  8.91s/it]
# Translating to es and back:  73%|███████▎  | 30/41 [05:34<02:03, 11.24s/it]
# Translating to es and back:  76%|███████▌  | 31/41 [05:42<01:40, 10.10s/it]
# Translating to es and back:  78%|███████▊  | 32/41 [05:47<01:17,  8.64s/it]
# Translating to es and back:  80%|████████  | 33/41 [05:56<01:09,  8.68s/it]
# Translating to es and back:  83%|████████▎ | 34/41 [06:04<01:00,  8.60s/it]
# Translating to es and back:  85%|████████▌ | 35/41 [06:13<00:52,  8.76s/it]
# Translating to es and back:  88%|████████▊ | 36/41 [06:22<00:43,  8.66s/it]
# Translating to es and back:  90%|█████████ | 37/41 [06:30<00:34,  8.69s/it]
# Translating to es and back:  93%|█████████▎| 38/41 [06:39<00:26,  8.69s/it]
# Translating to es and back:  95%|█████████▌| 39/41 [06:50<00:18,  9.24s/it]
# Translating to es and back:  98%|█████████▊| 40/41 [07:02<00:10, 10.10s/it]
# Translating to es and back: 100%|██████████| 41/41 [07:06<00:00, 10.41s/it]
# Processing languages:  28%|██▊       | 5/18 [38:47<1:38:23, 454.13s/it]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/803k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.60M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/307M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/803k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.60M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/307M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to ru and back:   0%|          | 0/41 [00:00<?, ?it/s]
# Translating to ru and back:   2%|▏         | 1/41 [00:10<07:16, 10.92s/it]
# Translating to ru and back:   5%|▍         | 2/41 [00:21<07:04, 10.88s/it]
# Translating to ru and back:   7%|▋         | 3/41 [00:33<07:12, 11.39s/it]
# Translating to ru and back:  10%|▉         | 4/41 [00:48<07:44, 12.56s/it]
# Translating to ru and back:  12%|█▏        | 5/41 [00:57<06:54, 11.52s/it]
# Translating to ru and back:  15%|█▍        | 6/41 [01:09<06:42, 11.49s/it]
# Translating to ru and back:  17%|█▋        | 7/41 [01:22<06:46, 11.96s/it]
# Translating to ru and back:  20%|█▉        | 8/41 [01:34<06:39, 12.11s/it]
# Translating to ru and back:  22%|██▏       | 9/41 [01:45<06:13, 11.68s/it]
# Translating to ru and back:  24%|██▍       | 10/41 [01:56<05:55, 11.48s/it]
# Translating to ru and back:  27%|██▋       | 11/41 [02:11<06:18, 12.62s/it]
# Translating to ru and back:  29%|██▉       | 12/41 [02:29<06:54, 14.30s/it]
# Translating to ru and back:  32%|███▏      | 13/41 [02:45<06:55, 14.83s/it]
# Translating to ru and back:  34%|███▍      | 14/41 [03:06<07:26, 16.54s/it]
# Translating to ru and back:  37%|███▋      | 15/41 [03:20<06:54, 15.94s/it]
# Translating to ru and back:  39%|███▉      | 16/41 [03:27<05:28, 13.15s/it]
# Translating to ru and back:  41%|████▏     | 17/41 [03:35<04:41, 11.73s/it]
# Translating to ru and back:  44%|████▍     | 18/41 [03:50<04:51, 12.67s/it]
# Translating to ru and back:  46%|████▋     | 19/41 [04:07<05:07, 13.99s/it]
# Translating to ru and back:  49%|████▉     | 20/41 [04:17<04:28, 12.81s/it]
# Translating to ru and back:  51%|█████     | 21/41 [04:30<04:12, 12.64s/it]
# Translating to ru and back:  54%|█████▎    | 22/41 [04:42<03:58, 12.58s/it]
# Translating to ru and back:  56%|█████▌    | 23/41 [05:00<04:17, 14.32s/it]
# Translating to ru and back:  59%|█████▊    | 24/41 [05:14<03:59, 14.08s/it]
# Translating to ru and back:  61%|██████    | 25/41 [05:23<03:19, 12.49s/it]
# Translating to ru and back:  63%|██████▎   | 26/41 [05:33<02:56, 11.79s/it]
# Translating to ru and back:  66%|██████▌   | 27/41 [05:45<02:45, 11.79s/it]
# Translating to ru and back:  68%|██████▊   | 28/41 [05:57<02:35, 11.98s/it]
# Translating to ru and back:  71%|███████   | 29/41 [06:11<02:29, 12.50s/it]
# Translating to ru and back:  73%|███████▎  | 30/41 [06:40<03:14, 17.65s/it]
# Translating to ru and back:  76%|███████▌  | 31/41 [06:48<02:26, 14.62s/it]
# Translating to ru and back:  78%|███████▊  | 32/41 [06:54<01:48, 12.04s/it]
# Translating to ru and back:  80%|████████  | 33/41 [07:09<01:44, 13.06s/it]
# Translating to ru and back:  83%|████████▎ | 34/41 [07:18<01:22, 11.79s/it]
# Translating to ru and back:  85%|████████▌ | 35/41 [07:27<01:05, 10.98s/it]
# Translating to ru and back:  88%|████████▊ | 36/41 [07:36<00:51, 10.32s/it]
# Translating to ru and back:  90%|█████████ | 37/41 [07:45<00:39,  9.95s/it]
# Translating to ru and back:  93%|█████████▎| 38/41 [07:54<00:29,  9.70s/it]
# Translating to ru and back:  95%|█████████▌| 39/41 [08:06<00:20, 10.20s/it]
# Translating to ru and back:  98%|█████████▊| 40/41 [08:18<00:10, 10.93s/it]
# Translating to ru and back: 100%|██████████| 41/41 [08:24<00:00, 12.30s/it]
# Processing languages:  33%|███▎      | 6/18 [47:26<1:35:12, 476.01s/it]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/801k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/917k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.12M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/917k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.13M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to ar and back:   0%|          | 0/41 [00:00<?, ?it/s]
# Translating to ar and back:   2%|▏         | 1/41 [00:16<10:55, 16.38s/it]Your input_length: 512 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to ar and back:   5%|▍         | 2/41 [00:45<15:24, 23.71s/it]
# Translating to ar and back:   7%|▋         | 3/41 [01:00<12:28, 19.70s/it]
# Translating to ar and back:  10%|▉         | 4/41 [01:13<10:38, 17.27s/it]
# Translating to ar and back:  12%|█▏        | 5/41 [01:23<08:38, 14.40s/it]
# Translating to ar and back:  15%|█▍        | 6/41 [01:38<08:33, 14.69s/it]
# Translating to ar and back:  17%|█▋        | 7/41 [02:04<10:24, 18.37s/it]
# Translating to ar and back:  20%|█▉        | 8/41 [02:51<15:07, 27.49s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to ar and back:  22%|██▏       | 9/41 [03:19<14:48, 27.75s/it]
# Translating to ar and back:  24%|██▍       | 10/41 [03:30<11:35, 22.44s/it]
# Translating to ar and back:  27%|██▋       | 11/41 [03:44<10:02, 20.07s/it]
# Translating to ar and back:  29%|██▉       | 12/41 [04:06<09:52, 20.44s/it]
# Translating to ar and back:  32%|███▏      | 13/41 [04:23<09:06, 19.53s/it]
# Translating to ar and back:  34%|███▍      | 14/41 [04:36<07:52, 17.51s/it]
# Translating to ar and back:  37%|███▋      | 15/41 [04:51<07:16, 16.79s/it]
# Translating to ar and back:  39%|███▉      | 16/41 [05:08<06:59, 16.77s/it]
# Translating to ar and back:  41%|████▏     | 17/41 [05:19<06:05, 15.24s/it]
# Translating to ar and back:  44%|████▍     | 18/41 [05:30<05:16, 13.75s/it]
# Translating to ar and back:  46%|████▋     | 19/41 [05:44<05:04, 13.83s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to ar and back:  49%|████▉     | 20/41 [06:01<05:14, 15.00s/it]
# Translating to ar and back:  51%|█████     | 21/41 [06:27<06:04, 18.21s/it]Your input_length: 512 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 512 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to ar and back:  54%|█████▎    | 22/41 [06:56<06:44, 21.28s/it]
# Translating to ar and back:  56%|█████▌    | 23/41 [07:05<05:20, 17.83s/it]
# Translating to ar and back:  59%|█████▊    | 24/41 [07:23<05:02, 17.77s/it]
# Translating to ar and back:  61%|██████    | 25/41 [07:34<04:10, 15.64s/it]
# Translating to ar and back:  63%|██████▎   | 26/41 [07:52<04:07, 16.50s/it]
# Translating to ar and back:  66%|██████▌   | 27/41 [08:08<03:49, 16.40s/it]
# Translating to ar and back:  68%|██████▊   | 28/41 [08:19<03:09, 14.56s/it]
# Translating to ar and back:  71%|███████   | 29/41 [08:30<02:43, 13.62s/it]
# Translating to ar and back:  73%|███████▎  | 30/41 [08:48<02:44, 14.94s/it]
# Translating to ar and back:  76%|███████▌  | 31/41 [09:03<02:30, 15.04s/it]
# Translating to ar and back:  78%|███████▊  | 32/41 [09:20<02:20, 15.63s/it]
# Translating to ar and back:  80%|████████  | 33/41 [09:33<01:59, 14.88s/it]
# Translating to ar and back:  83%|████████▎ | 34/41 [09:44<01:34, 13.47s/it]
# Translating to ar and back:  85%|████████▌ | 35/41 [09:54<01:15, 12.54s/it]
# Translating to ar and back:  88%|████████▊ | 36/41 [10:03<00:57, 11.42s/it]
# Translating to ar and back:  90%|█████████ | 37/41 [10:19<00:51, 12.88s/it]
# Translating to ar and back:  93%|█████████▎| 38/41 [10:30<00:36, 12.16s/it]
# Translating to ar and back:  95%|█████████▌| 39/41 [10:42<00:24, 12.15s/it]
# Translating to ar and back:  98%|█████████▊| 40/41 [10:54<00:12, 12.19s/it]Your input_length: 512 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to ar and back: 100%|██████████| 41/41 [11:07<00:00, 16.28s/it]
# Processing languages:  39%|███▉      | 7/18 [58:48<1:39:35, 543.23s/it]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/790k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/814k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.66M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/316M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/814k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/790k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.66M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/316M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to nl and back:   0%|          | 0/41 [00:00<?, ?it/s]
# Translating to nl and back:   2%|▏         | 1/41 [00:10<07:06, 10.66s/it]
# Translating to nl and back:   5%|▍         | 2/41 [00:20<06:35, 10.15s/it]
# Translating to nl and back:   7%|▋         | 3/41 [00:31<06:48, 10.74s/it]
# Translating to nl and back:  10%|▉         | 4/41 [00:46<07:31, 12.19s/it]
# Translating to nl and back:  12%|█▏        | 5/41 [00:58<07:23, 12.32s/it]
# Translating to nl and back:  15%|█▍        | 6/41 [01:10<07:01, 12.05s/it]
# Translating to nl and back:  17%|█▋        | 7/41 [01:22<06:54, 12.18s/it]
# Translating to nl and back:  20%|█▉        | 8/41 [01:33<06:28, 11.77s/it]
# Translating to nl and back:  22%|██▏       | 9/41 [01:43<05:53, 11.04s/it]
# Translating to nl and back:  24%|██▍       | 10/41 [01:51<05:17, 10.25s/it]
# Translating to nl and back:  27%|██▋       | 11/41 [02:06<05:48, 11.61s/it]
# Translating to nl and back:  29%|██▉       | 12/41 [02:22<06:17, 13.03s/it]
# Translating to nl and back:  32%|███▏      | 13/41 [02:37<06:18, 13.51s/it]
# Translating to nl and back:  34%|███▍      | 14/41 [02:50<06:01, 13.38s/it]
# Translating to nl and back:  37%|███▋      | 15/41 [03:01<05:27, 12.61s/it]
# Translating to nl and back:  39%|███▉      | 16/41 [03:07<04:30, 10.82s/it]
# Translating to nl and back:  41%|████▏     | 17/41 [03:18<04:16, 10.68s/it]
# Translating to nl and back:  44%|████▍     | 18/41 [03:31<04:22, 11.40s/it]
# Translating to nl and back:  46%|████▋     | 19/41 [03:40<03:56, 10.74s/it]
# Translating to nl and back:  49%|████▉     | 20/41 [03:50<03:40, 10.51s/it]
# Translating to nl and back:  51%|█████     | 21/41 [04:00<03:26, 10.32s/it]
# Translating to nl and back:  54%|█████▎    | 22/41 [04:13<03:34, 11.28s/it]
# Translating to nl and back:  56%|█████▌    | 23/41 [04:24<03:20, 11.13s/it]
# Translating to nl and back:  59%|█████▊    | 24/41 [04:34<03:01, 10.69s/it]
# Translating to nl and back:  61%|██████    | 25/41 [04:42<02:41, 10.09s/it]
# Translating to nl and back:  63%|██████▎   | 26/41 [04:52<02:30, 10.05s/it]
# Translating to nl and back:  66%|██████▌   | 27/41 [05:04<02:27, 10.55s/it]
# Translating to nl and back:  68%|██████▊   | 28/41 [05:12<02:05,  9.64s/it]
# Translating to nl and back:  71%|███████   | 29/41 [05:19<01:48,  9.06s/it]
# Translating to nl and back:  73%|███████▎  | 30/41 [05:28<01:37,  8.88s/it]
# Translating to nl and back:  76%|███████▌  | 31/41 [05:35<01:24,  8.45s/it]
# Translating to nl and back:  78%|███████▊  | 32/41 [05:41<01:09,  7.69s/it]
# Translating to nl and back:  80%|████████  | 33/41 [05:50<01:04,  8.04s/it]
# Translating to nl and back:  83%|████████▎ | 34/41 [06:00<01:01,  8.73s/it]
# Translating to nl and back:  85%|████████▌ | 35/41 [06:09<00:52,  8.82s/it]
# Translating to nl and back:  88%|████████▊ | 36/41 [06:18<00:43,  8.65s/it]
# Translating to nl and back:  90%|█████████ | 37/41 [06:28<00:36,  9.20s/it]
# Translating to nl and back:  93%|█████████▎| 38/41 [06:37<00:27,  9.22s/it]
# Translating to nl and back:  95%|█████████▌| 39/41 [06:48<00:19,  9.66s/it]
# Translating to nl and back:  98%|█████████▊| 40/41 [07:00<00:10, 10.32s/it]
# Translating to nl and back: 100%|██████████| 41/41 [07:06<00:00, 10.41s/it]
# Processing languages:  44%|████▍     | 8/18 [1:06:13<1:25:20, 512.06s/it]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/789k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/814k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.35M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/343M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/814k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/790k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.37M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/344M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to it and back:   0%|          | 0/41 [00:00<?, ?it/s]
# Translating to it and back:   2%|▏         | 1/41 [00:11<07:51, 11.79s/it]
# Translating to it and back:   5%|▍         | 2/41 [00:22<07:09, 11.02s/it]
# Translating to it and back:   7%|▋         | 3/41 [00:34<07:26, 11.74s/it]
# Translating to it and back:  10%|▉         | 4/41 [00:49<07:57, 12.91s/it]
# Translating to it and back:  12%|█▏        | 5/41 [01:00<07:15, 12.10s/it]
# Translating to it and back:  15%|█▍        | 6/41 [01:12<07:04, 12.13s/it]
# Translating to it and back:  17%|█▋        | 7/41 [01:25<07:02, 12.43s/it]
# Translating to it and back:  20%|█▉        | 8/41 [01:37<06:47, 12.36s/it]
# Translating to it and back:  22%|██▏       | 9/41 [01:47<06:13, 11.67s/it]
# Translating to it and back:  24%|██▍       | 10/41 [01:56<05:32, 10.71s/it]
# Translating to it and back:  27%|██▋       | 11/41 [02:11<06:04, 12.16s/it]
# Translating to it and back:  29%|██▉       | 12/41 [02:29<06:41, 13.84s/it]
# Translating to it and back:  32%|███▏      | 13/41 [02:45<06:44, 14.44s/it]
# Translating to it and back:  34%|███▍      | 14/41 [02:59<06:23, 14.20s/it]
# Translating to it and back:  37%|███▋      | 15/41 [03:10<05:45, 13.29s/it]
# Translating to it and back:  39%|███▉      | 16/41 [03:16<04:39, 11.20s/it]
# Translating to it and back:  41%|████▏     | 17/41 [03:25<04:13, 10.57s/it]
# Translating to it and back:  44%|████▍     | 18/41 [03:35<03:55, 10.22s/it]
# Translating to it and back:  46%|████▋     | 19/41 [03:44<03:43, 10.14s/it]
# Translating to it and back:  49%|████▉     | 20/41 [03:55<03:35, 10.26s/it]
# Translating to it and back:  51%|█████     | 21/41 [04:05<03:25, 10.26s/it]
# Translating to it and back:  54%|█████▎    | 22/41 [04:18<03:27, 10.90s/it]
# Translating to it and back:  56%|█████▌    | 23/41 [04:26<03:01, 10.07s/it]
# Translating to it and back:  59%|█████▊    | 24/41 [04:37<02:54, 10.26s/it]
# Translating to it and back:  61%|██████    | 25/41 [04:45<02:36,  9.81s/it]
# Translating to it and back:  63%|██████▎   | 26/41 [04:57<02:34, 10.31s/it]
# Translating to it and back:  66%|██████▌   | 27/41 [05:09<02:33, 10.95s/it]
# Translating to it and back:  68%|██████▊   | 28/41 [05:17<02:09,  9.98s/it]
# Translating to it and back:  71%|███████   | 29/41 [05:25<01:53,  9.44s/it]
# Translating to it and back:  73%|███████▎  | 30/41 [05:34<01:43,  9.42s/it]
# Translating to it and back:  76%|███████▌  | 31/41 [05:42<01:29,  8.97s/it]
# Translating to it and back:  78%|███████▊  | 32/41 [05:49<01:15,  8.37s/it]
# Translating to it and back:  80%|████████  | 33/41 [06:01<01:13,  9.24s/it]
# Translating to it and back:  83%|████████▎ | 34/41 [06:15<01:14, 10.64s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to it and back:  85%|████████▌ | 35/41 [06:32<01:16, 12.81s/it]
# Translating to it and back:  88%|████████▊ | 36/41 [06:43<01:00, 12.11s/it]
# Translating to it and back:  90%|█████████ | 37/41 [06:52<00:45, 11.26s/it]
# Translating to it and back:  93%|█████████▎| 38/41 [07:01<00:31, 10.66s/it]
# Translating to it and back:  95%|█████████▌| 39/41 [07:13<00:21, 10.93s/it]
# Translating to it and back:  98%|█████████▊| 40/41 [07:26<00:11, 11.48s/it]
# Translating to it and back: 100%|██████████| 41/41 [07:31<00:00, 11.01s/it]
# Processing languages:  50%|█████     | 9/18 [1:14:00<1:14:43, 498.16s/it]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/803k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/815k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.26M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/292M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/815k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/803k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.26M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/292M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to ca and back:   0%|          | 0/41 [00:00<?, ?it/s]
# Translating to ca and back:   2%|▏         | 1/41 [00:09<06:35,  9.88s/it]
# Translating to ca and back:   5%|▍         | 2/41 [00:20<06:35, 10.15s/it]
# Translating to ca and back:   7%|▋         | 3/41 [00:31<06:45, 10.66s/it]
# Translating to ca and back:  10%|▉         | 4/41 [00:45<07:20, 11.90s/it]
# Translating to ca and back:  12%|█▏        | 5/41 [00:55<06:43, 11.20s/it]
# Translating to ca and back:  15%|█▍        | 6/41 [01:06<06:34, 11.28s/it]
# Translating to ca and back:  17%|█▋        | 7/41 [01:18<06:30, 11.49s/it]
# Translating to ca and back:  20%|█▉        | 8/41 [01:29<06:08, 11.17s/it]
# Translating to ca and back:  22%|██▏       | 9/41 [01:37<05:31, 10.36s/it]
# Translating to ca and back:  24%|██▍       | 10/41 [01:45<04:59,  9.67s/it]
# Translating to ca and back:  27%|██▋       | 11/41 [01:59<05:31, 11.03s/it]
# Translating to ca and back:  29%|██▉       | 12/41 [02:14<05:54, 12.22s/it]
# Translating to ca and back:  32%|███▏      | 13/41 [02:28<05:55, 12.71s/it]
# Translating to ca and back:  34%|███▍      | 14/41 [02:40<05:35, 12.42s/it]
# Translating to ca and back:  37%|███▋      | 15/41 [02:50<05:04, 11.73s/it]
# Translating to ca and back:  39%|███▉      | 16/41 [03:01<04:44, 11.38s/it]
# Translating to ca and back:  41%|████▏     | 17/41 [03:09<04:10, 10.42s/it]
# Translating to ca and back:  44%|████▍     | 18/41 [03:18<03:48,  9.92s/it]
# Translating to ca and back:  46%|████▋     | 19/41 [03:27<03:33,  9.69s/it]
# Translating to ca and back:  49%|████▉     | 20/41 [03:36<03:22,  9.64s/it]
# Translating to ca and back:  51%|█████     | 21/41 [03:45<03:10,  9.51s/it]
# Translating to ca and back:  54%|█████▎    | 22/41 [03:57<03:11, 10.07s/it]
# Translating to ca and back:  56%|█████▌    | 23/41 [04:04<02:45,  9.20s/it]
# Translating to ca and back:  59%|█████▊    | 24/41 [04:13<02:36,  9.23s/it]
# Translating to ca and back:  61%|██████    | 25/41 [04:22<02:23,  8.95s/it]
# Translating to ca and back:  63%|██████▎   | 26/41 [04:31<02:16,  9.13s/it]
# Translating to ca and back:  66%|██████▌   | 27/41 [04:43<02:17,  9.82s/it]
# Translating to ca and back:  68%|██████▊   | 28/41 [04:50<01:58,  9.12s/it]
# Translating to ca and back:  71%|███████   | 29/41 [04:57<01:42,  8.54s/it]
# Translating to ca and back:  73%|███████▎  | 30/41 [05:05<01:32,  8.42s/it]
# Translating to ca and back:  76%|███████▌  | 31/41 [05:12<01:19,  7.98s/it]
# Translating to ca and back:  78%|███████▊  | 32/41 [05:18<01:04,  7.22s/it]
# Translating to ca and back:  80%|████████  | 33/41 [05:26<01:00,  7.56s/it]
# Translating to ca and back:  83%|████████▎ | 34/41 [05:34<00:54,  7.79s/it]
# Translating to ca and back:  85%|████████▌ | 35/41 [05:43<00:48,  8.03s/it]
# Translating to ca and back:  88%|████████▊ | 36/41 [05:52<00:40,  8.15s/it]
# Translating to ca and back:  90%|█████████ | 37/41 [06:00<00:33,  8.32s/it]
# Translating to ca and back:  93%|█████████▎| 38/41 [06:09<00:25,  8.47s/it]
# Translating to ca and back:  95%|█████████▌| 39/41 [06:20<00:18,  9.07s/it]
# Translating to ca and back:  98%|█████████▊| 40/41 [06:31<00:09,  9.74s/it]
# Translating to ca and back: 100%|██████████| 41/41 [06:35<00:00,  9.65s/it]
# Processing languages:  56%|█████▌    | 10/18 [1:20:55<1:02:59, 472.46s/it]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/800k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/820k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/293M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/450k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/443k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/472k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/222M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to gl and back:   0%|          | 0/41 [00:00<?, ?it/s]
# Translating to gl and back:   2%|▏         | 1/41 [00:09<06:24,  9.60s/it]
# Translating to gl and back:   5%|▍         | 2/41 [00:18<06:01,  9.28s/it]
# Translating to gl and back:   7%|▋         | 3/41 [00:29<06:11,  9.78s/it]
# Translating to gl and back:  10%|▉         | 4/41 [00:41<06:44, 10.93s/it]
# Translating to gl and back:  12%|█▏        | 5/41 [00:50<06:11, 10.31s/it]
# Translating to gl and back:  15%|█▍        | 6/41 [01:01<06:06, 10.46s/it]
# Translating to gl and back:  17%|█▋        | 7/41 [01:12<06:03, 10.70s/it]
# Translating to gl and back:  20%|█▉        | 8/41 [01:22<05:44, 10.44s/it]
# Translating to gl and back:  22%|██▏       | 9/41 [01:31<05:14,  9.83s/it]
# Translating to gl and back:  24%|██▍       | 10/41 [01:38<04:37,  8.96s/it]
# Translating to gl and back:  27%|██▋       | 11/41 [01:51<05:03, 10.12s/it]
# Translating to gl and back:  29%|██▉       | 12/41 [02:05<05:30, 11.40s/it]
# Translating to gl and back:  32%|███▏      | 13/41 [02:18<05:32, 11.89s/it]
# Translating to gl and back:  34%|███▍      | 14/41 [02:29<05:16, 11.74s/it]
# Translating to gl and back:  37%|███▋      | 15/41 [02:39<04:48, 11.10s/it]
# Translating to gl and back:  39%|███▉      | 16/41 [02:45<03:57,  9.51s/it]
# Translating to gl and back:  41%|████▏     | 17/41 [02:52<03:34,  8.93s/it]
# Translating to gl and back:  44%|████▍     | 18/41 [03:01<03:23,  8.85s/it]
# Translating to gl and back:  46%|████▋     | 19/41 [03:10<03:14,  8.83s/it]
# Translating to gl and back:  49%|████▉     | 20/41 [03:19<03:07,  8.91s/it]
# Translating to gl and back:  51%|█████     | 21/41 [03:28<03:00,  9.04s/it]
# Translating to gl and back:  54%|█████▎    | 22/41 [03:39<03:04,  9.70s/it]
# Translating to gl and back:  56%|█████▌    | 23/41 [03:46<02:35,  8.65s/it]
# Translating to gl and back:  59%|█████▊    | 24/41 [03:54<02:27,  8.66s/it]
# Translating to gl and back:  61%|██████    | 25/41 [04:03<02:16,  8.54s/it]
# Translating to gl and back:  63%|██████▎   | 26/41 [04:12<02:10,  8.73s/it]
# Translating to gl and back:  66%|██████▌   | 27/41 [04:23<02:12,  9.45s/it]
# Translating to gl and back:  68%|██████▊   | 28/41 [04:30<01:52,  8.68s/it]
# Translating to gl and back:  71%|███████   | 29/41 [04:37<01:38,  8.21s/it]
# Translating to gl and back:  73%|███████▎  | 30/41 [04:45<01:28,  8.05s/it]
# Translating to gl and back:  76%|███████▌  | 31/41 [04:51<01:16,  7.68s/it]
# Translating to gl and back:  78%|███████▊  | 32/41 [04:57<01:03,  7.01s/it]
# ...
#
# Translating to vi and back:  63%|██████▎   | 26/41 [17:59<09:44, 38.96s/it]
# Translating to vi and back:  66%|██████▌   | 27/41 [18:11<07:10, 30.77s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to vi and back:  68%|██████▊   | 28/41 [19:07<08:21, 38.56s/it]
# Translating to vi and back:  71%|███████   | 29/41 [19:28<06:38, 33.19s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to vi and back:  73%|███████▎  | 30/41 [20:12<06:41, 36.51s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 479 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to vi and back:  76%|███████▌  | 31/41 [20:38<05:33, 33.31s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to vi and back:  78%|███████▊  | 32/41 [21:32<05:54, 39.38s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to vi and back:  80%|████████  | 33/41 [22:27<05:52, 44.09s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 506 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to vi and back:  83%|████████▎ | 34/41 [22:57<04:39, 39.94s/it]Your input_length: 510 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to vi and back:  85%|████████▌ | 35/41 [23:15<03:19, 33.23s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to vi and back:  88%|████████▊ | 36/41 [23:51<02:50, 34.09s/it]Your input_length: 509 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to vi and back:  90%|█████████ | 37/41 [24:37<02:31, 37.77s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to vi and back:  93%|█████████▎| 38/41 [25:30<02:07, 42.40s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 493 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to vi and back:  95%|█████████▌| 39/41 [25:58<01:16, 38.06s/it]
# Translating to vi and back:  98%|█████████▊| 40/41 [26:09<00:30, 30.03s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 470 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to vi and back: 100%|██████████| 41/41 [26:32<00:00, 38.84s/it]
# Processing languages:  89%|████████▉ | 16/18 [2:48:27<30:05, 902.92s/it]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/786k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/793k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.26M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/295M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/265 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/800k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/779k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.46M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to roa and back:   0%|          | 0/41 [00:00<?, ?it/s]
# Translating to roa and back:   2%|▏         | 1/41 [00:15<10:25, 15.64s/it]
# Translating to roa and back:   5%|▍         | 2/41 [00:26<08:30, 13.09s/it]
# Translating to roa and back:   7%|▋         | 3/41 [00:39<08:13, 12.98s/it]
# Translating to roa and back:  10%|▉         | 4/41 [00:55<08:43, 14.16s/it]
# Translating to roa and back:  12%|█▏        | 5/41 [01:06<07:45, 12.94s/it]
# Translating to roa and back:  15%|█▍        | 6/41 [01:19<07:29, 12.85s/it]
# Translating to roa and back:  17%|█▋        | 7/41 [01:32<07:20, 12.95s/it]
# Translating to roa and back:  20%|█▉        | 8/41 [01:44<06:54, 12.57s/it]
# Translating to roa and back:  22%|██▏       | 9/41 [01:54<06:18, 11.81s/it]
# Translating to roa and back:  24%|██▍       | 10/41 [02:09<06:38, 12.87s/it]
# Translating to roa and back:  27%|██▋       | 11/41 [02:25<06:52, 13.74s/it]
# Translating to roa and back:  29%|██▉       | 12/41 [02:42<07:11, 14.86s/it]
# Translating to roa and back:  32%|███▏      | 13/41 [03:03<07:45, 16.64s/it]
# Translating to roa and back:  34%|███▍      | 14/41 [03:17<07:05, 15.74s/it]
# Translating to roa and back:  37%|███▋      | 15/41 [03:28<06:15, 14.45s/it]
# Translating to roa and back:  39%|███▉      | 16/41 [03:35<05:06, 12.25s/it]
# Translating to roa and back:  41%|████▏     | 17/41 [03:44<04:26, 11.12s/it]
# Translating to roa and back:  44%|████▍     | 18/41 [03:53<04:03, 10.57s/it]
# Translating to roa and back:  46%|████▋     | 19/41 [04:06<04:07, 11.26s/it]
# Translating to roa and back:  49%|████▉     | 20/41 [04:20<04:17, 12.25s/it]
# Translating to roa and back:  51%|█████     | 21/41 [04:31<03:54, 11.71s/it]
# Translating to roa and back:  54%|█████▎    | 22/41 [04:46<03:59, 12.60s/it]
# Translating to roa and back:  56%|█████▌    | 23/41 [05:02<04:06, 13.68s/it]
# Translating to roa and back:  59%|█████▊    | 24/41 [05:12<03:34, 12.64s/it]
# Translating to roa and back:  61%|██████    | 25/41 [05:21<03:04, 11.54s/it]
# Translating to roa and back:  63%|██████▎   | 26/41 [05:31<02:48, 11.21s/it]
# Translating to roa and back:  66%|██████▌   | 27/41 [05:44<02:41, 11.55s/it]
# Translating to roa and back:  68%|██████▊   | 28/41 [05:52<02:15, 10.43s/it]
# Translating to roa and back:  71%|███████   | 29/41 [06:05<02:14, 11.24s/it]
# Translating to roa and back:  73%|███████▎  | 30/41 [06:17<02:06, 11.46s/it]
# Translating to roa and back:  76%|███████▌  | 31/41 [06:24<01:42, 10.30s/it]
# Translating to roa and back:  78%|███████▊  | 32/41 [06:37<01:39, 11.09s/it]
# Translating to roa and back:  80%|████████  | 33/41 [06:49<01:30, 11.37s/it]
# Translating to roa and back:  83%|████████▎ | 34/41 [07:02<01:22, 11.72s/it]
# Translating to roa and back:  85%|████████▌ | 35/41 [07:11<01:05, 11.00s/it]
# Translating to roa and back:  88%|████████▊ | 36/41 [07:22<00:55, 11.15s/it]
# Translating to roa and back:  90%|█████████ | 37/41 [07:31<00:41, 10.50s/it]
# Translating to roa and back:  93%|█████████▎| 38/41 [07:41<00:30, 10.32s/it]
# Translating to roa and back:  95%|█████████▌| 39/41 [07:52<00:21, 10.56s/it]
# Translating to roa and back:  98%|█████████▊| 40/41 [08:05<00:11, 11.25s/it]
# Translating to roa and back: 100%|██████████| 41/41 [08:10<00:00, 11.97s/it]
# Processing languages:  94%|█████████▍| 17/18 [2:56:59<13:05, 785.34s/it]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/790k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/815k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/295M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/815k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/790k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/295M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to sv and back:   0%|          | 0/41 [00:00<?, ?it/s]
# Translating to sv and back:   2%|▏         | 1/41 [00:09<06:32,  9.82s/it]
# Translating to sv and back:   5%|▍         | 2/41 [00:19<06:15,  9.62s/it]
# Translating to sv and back:   7%|▋         | 3/41 [00:30<06:27, 10.20s/it]
# Translating to sv and back:  10%|▉         | 4/41 [00:43<06:56, 11.26s/it]
# Translating to sv and back:  12%|█▏        | 5/41 [00:52<06:17, 10.49s/it]
# Translating to sv and back:  15%|█▍        | 6/41 [01:03<06:15, 10.72s/it]
# Translating to sv and back:  17%|█▋        | 7/41 [01:14<06:11, 10.93s/it]
# Translating to sv and back:  20%|█▉        | 8/41 [01:24<05:50, 10.62s/it]
# Translating to sv and back:  22%|██▏       | 9/41 [01:33<05:20, 10.00s/it]
# Translating to sv and back:  24%|██▍       | 10/41 [01:41<04:50,  9.36s/it]
# Translating to sv and back:  27%|██▋       | 11/41 [01:54<05:20, 10.68s/it]
# Translating to sv and back:  29%|██▉       | 12/41 [02:09<05:47, 11.97s/it]
# Translating to sv and back:  32%|███▏      | 13/41 [02:23<05:46, 12.39s/it]
# Translating to sv and back:  34%|███▍      | 14/41 [02:35<05:32, 12.30s/it]
# Translating to sv and back:  37%|███▋      | 15/41 [02:45<05:00, 11.57s/it]
# Translating to sv and back:  39%|███▉      | 16/41 [02:51<04:06,  9.87s/it]
# Translating to sv and back:  41%|████▏     | 17/41 [02:59<03:43,  9.33s/it]
# Translating to sv and back:  44%|████▍     | 18/41 [03:07<03:30,  9.16s/it]
# Translating to sv and back:  46%|████▋     | 19/41 [03:16<03:17,  8.99s/it]
# Translating to sv and back:  49%|████▉     | 20/41 [03:25<03:10,  9.08s/it]
# Translating to sv and back:  51%|█████     | 21/41 [03:34<03:00,  9.05s/it]
# Translating to sv and back:  54%|█████▎    | 22/41 [03:45<03:00,  9.51s/it]
# Translating to sv and back:  56%|█████▌    | 23/41 [03:57<03:02, 10.14s/it]
# Translating to sv and back:  59%|█████▊    | 24/41 [04:06<02:49, 10.00s/it]
# Translating to sv and back:  61%|██████    | 25/41 [04:14<02:31,  9.45s/it]
# Translating to sv and back:  63%|██████▎   | 26/41 [04:24<02:22,  9.50s/it]
# Translating to sv and back:  66%|██████▌   | 27/41 [04:35<02:19,  9.95s/it]
# Translating to sv and back:  68%|██████▊   | 28/41 [04:42<01:58,  9.13s/it]
# Translating to sv and back:  71%|███████   | 29/41 [04:49<01:42,  8.57s/it]
# Translating to sv and back:  73%|███████▎  | 30/41 [05:00<01:40,  9.17s/it]
# Translating to sv and back:  76%|███████▌  | 31/41 [05:07<01:25,  8.57s/it]
# Translating to sv and back:  78%|███████▊  | 32/41 [05:12<01:07,  7.55s/it]
# Translating to sv and back:  80%|████████  | 33/41 [05:21<01:02,  7.85s/it]
# Translating to sv and back:  83%|████████▎ | 34/41 [05:29<00:55,  7.90s/it]
# Translating to sv and back:  85%|████████▌ | 35/41 [05:37<00:48,  8.07s/it]
# Translating to sv and back:  88%|████████▊ | 36/41 [05:45<00:39,  7.90s/it]
# Translating to sv and back:  90%|█████████ | 37/41 [05:54<00:32,  8.14s/it]
# Translating to sv and back:  93%|█████████▎| 38/41 [06:02<00:24,  8.26s/it]
# Translating to sv and back:  95%|█████████▌| 39/41 [06:12<00:17,  8.72s/it]
# Translating to sv and back:  98%|█████████▊| 40/41 [06:23<00:09,  9.48s/it]
# Translating to sv and back: 100%|██████████| 41/41 [06:28<00:00,  9.47s/it]
# Processing languages: 100%|██████████| 18/18 [3:03:41<00:00, 612.31s/it]

# %%
ds=df.to_pandas()
ds = ds.drop(columns=["index"])
ds.reset_index(inplace=True)
if torch.cuda.is_available():
    torch.cuda.empty_cache()
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1298 entries, 0 to 1297
# Data columns (total 24 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   index                               1298 non-null   int64
#  1   class                               1298 non-null   object
#  2   comment_sentence                    1298 non-null   object
#  3   partition                           1298 non-null   int64
#  4   combo                               1298 non-null   object
#  5   labels                              1298 non-null   object
#  6   retranslated_text_english_from_de   1298 non-null   object
#  7   retranslated_text_english_from_fr   1298 non-null   object
#  8   retranslated_text_english_from_zh   1298 non-null   object
#  9   retranslated_text_english_from_hi   1298 non-null   object
#  10  retranslated_text_english_from_es   1298 non-null   object
#  11  retranslated_text_english_from_ru   1298 non-null   object
#  12  retranslated_text_english_from_ar   1298 non-null   object
#  13  retranslated_text_english_from_nl   1298 non-null   object
#  14  retranslated_text_english_from_it   1298 non-null   object
#  15  retranslated_text_english_from_ca   1298 non-null   object
#  16  retranslated_text_english_from_gl   1298 non-null   object
#  17  retranslated_text_english_from_grk  1298 non-null   object
#  18  retranslated_text_english_from_trk  1298 non-null   object
#  19  retranslated_text_english_from_uk   1298 non-null   object
#  20  retranslated_text_english_from_ur   1298 non-null   object
#  21  retranslated_text_english_from_vi   1298 non-null   object
#  22  retranslated_text_english_from_roa  1298 non-null   object
#  23  retranslated_text_english_from_sv   1298 non-null   object
# dtypes: int64(2), object(22)
# memory usage: 243.5+ KB

# %%
# Define the model and tokenizer for sentence encoding
model_name = "sentence-transformers/all-MiniLM-L6-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name).to("cuda" if torch.cuda.is_available() else "cpu")

# List of languages for retranslation analysis

languages = ["de", "fr", "zh", "hi", "es", "ru","ar","nl","it","ca","gl","grk","trk","uk","ur","vi","roa","sv"]

# Function to encode sentences in batches for efficiency
def encode_sentences_in_batches(sentences, batch_size=32):
    """
    Encodes a list of sentences in batches using the pre-trained model.
    Args:
        sentences (list): List of sentences to encode.
        batch_size (int): Size of each batch for encoding.
    Returns:
        torch.Tensor: Tensor containing embeddings for all sentences.
    """
    embeddings = []
    for i in range(0, len(sentences), batch_size):
        batch = sentences[i:i+batch_size]
        # Tokenize and move inputs to the appropriate device (CPU/GPU)
        inputs = tokenizer(batch, padding=True, truncation=True, return_tensors="pt").to("cuda" if torch.cuda.is_available() else "cpu")
        with torch.no_grad():  # Disable gradient computation for inference
            model_output = model(**inputs)
        # Take the mean of the last hidden state to get sentence embeddings
        embeddings.append(model_output.last_hidden_state.mean(dim=1).cpu())
    return torch.cat(embeddings)

# Generate embeddings for original comments
comment_embeddings = encode_sentences_in_batches(ds['comment_sentence'].tolist())

# Set a cosine similarity threshold for filtering translations
threshold = 0.7

# Generate embeddings and filter translations for each language
language_columns = [f"retranslated_text_english_from_{lang}" for lang in languages]
for lang_col in language_columns:
    # Generate embeddings for the retranslated sentences
    retranslated_embeddings = encode_sentences_in_batches(ds[lang_col].fillna("").tolist())
    # Compute cosine similarity between original and retranslated embeddings
    cosine_similarities = torch.nn.functional.cosine_similarity(comment_embeddings, retranslated_embeddings).tolist()

    # Filter translations based on similarity threshold
    filtered_translation_col = f"filtered_{lang_col}"
    ds[filtered_translation_col] = [
        row[lang_col] if similarity > threshold else ""  # Keep translation if similarity exceeds threshold
        for (_, row), similarity in zip(ds.iterrows(), cosine_similarities)
    ]

# Prepare for concatenating original and filtered translations
main_columns = ['class', 'comment_sentence', 'labels']  # Main columns to retain in the final dataset
concat_columns = [f"filtered_{lang}" for lang in language_columns]  # Columns containing filtered translations

concat_types = ["de", "fr", "zh", "hi", "es", "ru","ar","nl","it","ca","gl","grk","trk","uk","ur","vi","roa","sv"]

# Create a new DataFrame with original data
df_main = ds[main_columns].copy()
df_main['types'] = 'original'  # Add a column to indicate original comments

# Initialize a list to hold concatenated DataFrames
concat_data = [df_main]

# Add filtered translations to the concatenated DataFrame
for col, col_type in zip(concat_columns, concat_types):
    temp_df = df_main[main_columns].copy()  # Copy main structure
    temp_df['comment_sentence'] = ds[col]  # Replace 'comment_sentence' with filtered translations
    temp_df['types'] = col_type  # Label the type of translation
    concat_data.append(temp_df)  # Append to the list

# Concatenate all DataFrames into one
df_extended = pd.concat(concat_data, ignore_index=True)

# Remove rows with empty or null 'comment_sentence' values
df_extended = df_extended.dropna()  # Drop rows with null values
df_extended = df_extended[df_extended['comment_sentence'] != ""].reset_index(drop=True)  # Drop empty strings
# Display dataset information for debugging or confirmation
df_extended.info()
# Out:
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17508 entries, 0 to 17507
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   class             17508 non-null  object
#  1   comment_sentence  17508 non-null  object
#  2   labels            17508 non-null  object
#  3   types             17508 non-null  object
# dtypes: object(4)
# memory usage: 547.2+ KB

# %%
file_path = 'NLBSE_Dataset_Pharo.csv'

# Save the DataFrame to a CSV file
df_extended.to_csv(file_path, index=False)
print(f"DataFrame saved to {file_path}")
# Out:
# DataFrame saved to NLBSE_Dataset_Pharo.csv
