# %% [markdown]
# # Run in kaggle T4 * 2 gpu

# %%
# %pip install transformers
# %pip install datasets
# %pip install accelerate
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.45.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.25.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets) (3.15.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/conda/lib/python3.10/site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.22.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.25.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.22.0->datasets) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->datasets) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (0.34.2)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /opt/conda/lib/python3.10/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (2.4.0)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.4.5)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (2024.6.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->accelerate) (3.1.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings("ignore")
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline, AutoModel
import torch
from datasets import load_dataset
import pandas as pd
from tqdm import tqdm
from accelerate import Accelerator

# %%
if torch.cuda.is_available():
    # Get the number of GPUs available
    num_gpus = torch.cuda.device_count()
    print(f"Number of GPUs available: {num_gpus}")
    
    # Print out the name of each GPU and memory details
    for i in range(num_gpus):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
        print(f"Total memory: {torch.cuda.get_device_properties(i).total_memory / 1e9} GB")
    
    # If multiple GPUs are available, use DataParallel for multi-GPU
    if num_gpus > 1:
        print("Using DataParallel for multi-GPU training.")
        # Example: Wrap your model with DataParallel
    else:
        print("Only one GPU available, using single GPU mode.")
else:
    print("No GPUs available, using CPU.")
    
def setup_translation_pipeline(source_lang, target_lang):
    """
    Set up a translation pipeline using a pretrained model from Helsinki-NLP, optimized for multi-GPU with Accelerate.

    Args:
        source_lang (str): The source language code (e.g., "en" for English).
        target_lang (str): The target language code (e.g., "fr" for French).

    Returns:
        transformers.Pipeline: A translation pipeline configured for the given language pair.
    """
    # Define the model name based on the source and target languages
    model_name = f"Helsinki-NLP/opus-mt-{source_lang}-{target_lang}"
    
    # Load the tokenizer for the specified model
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    
    # Load the translation model with memory optimization and half-precision support
    model = AutoModelForSeq2SeqLM.from_pretrained(
        model_name,
        return_dict=True,  # Use a dictionary for the model's output for easier access
        low_cpu_mem_usage=True,  # Optimize for low memory usage during model loading
        torch_dtype=torch.float16,  # Use half-precision for faster computation (requires supported GPU)
        trust_remote_code=True,  # Trust the model's remote configuration if specified
    )
    
    # Use the Accelerate library for better multi-GPU support
    accelerator = Accelerator()

    # Move the model to the appropriate device using Accelerator (handles multi-GPU)
    model = accelerator.prepare(model)

    # Set up and return the translation pipeline
    translation_pipeline = pipeline(
        "translation",  # Specify the task as translation
        model=model,  # Provide the loaded model
        tokenizer=tokenizer,  # Provide the loaded tokenizer
        torch_dtype=torch.float16,  # Use half-precision for the pipeline
        max_length=512,
        truncation=True,
        device=accelerator.device  # Use the device from Accelerator (handles multi-GPU)
    )

    return translation_pipeline
# Out:
# Number of GPUs available: 2
# GPU 0: Tesla T4
# Total memory: 15.828320256 GB
# GPU 1: Tesla T4
# Total memory: 15.828320256 GB
# Using DataParallel for multi-GPU training.

# %%
# Function to translate and retranslate for a given target language
def translate_retranslate(ds, source_lang, target_lang, batch_size=32):
    """
    Translate the dataset's 'comment_sentence' column to a target language and back to the source language.
    
    Args:
        ds (Dataset): Hugging Face dataset containing a 'comment_sentence' column.
        source_lang (str): Source language code (e.g., "en" for English).
        target_lang (str): Target language code to translate to and back.
        batch_size (int): Number of rows to process in a single batch.

    Returns:
        Dataset: Hugging Face dataset with a new column for retranslated texts.
    """
    # Set up translation pipelines
    pipe_to_target = setup_translation_pipeline(source_lang, target_lang)  # English to target language
    pipe_to_source = setup_translation_pipeline(target_lang, source_lang)  # Target language back to English

    retranslated_texts = []

    # Process the dataset in batches to optimize memory usage and speed
    for i in tqdm(range(0, len(ds), batch_size), desc=f"Translating to {target_lang} and back"):
        # Extract a batch of 'comment_sentence' without converting to pandas
        batch = ds[i: i + batch_size]["comment_sentence"]

        # Step 1: Translate from source language to target language
        target_translations = pipe_to_target(batch, max_length=512, do_sample=False)
        target_texts = [result["translation_text"] for result in target_translations]

        # Step 2: Translate back to the source language (English)
        english_translations = pipe_to_source(target_texts, max_length=512, do_sample=False)
        retranslated_batch = [result["translation_text"].strip() for result in english_translations]

        # Append the retranslated texts to the result list
        retranslated_texts.extend(retranslated_batch)
                # Clear CUDA cache to prevent memory overload
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    # Add the retranslated texts as a new column in the dataset
    ds = ds.add_column(f"retranslated_text_english_from_{target_lang}", retranslated_texts)
    return ds

# Load the dataset (e.g., the first 10 rows from the Python training split)
df = load_dataset("NLBSE/nlbse25-code-comment-classification", split="java_train")

# List of target languages to process for retranslation
languages = ["de", "fr", "zh", "hi", "es", "ru"]

# Loop through each language and retranslate
for lang in tqdm(languages, desc="Processing languages"):
    df = translate_retranslate(df, "en", lang)
# Out:
# README.md:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# java_train-00000-of-00001.parquet:   0%|          | 0.00/680k [00:00<?, ?B/s]
# java_test-00000-of-00001.parquet:   0%|          | 0.00/174k [00:00<?, ?B/s]
# python_train-00000-of-00001.parquet:   0%|          | 0.00/126k [00:00<?, ?B/s]
# python_test-00000-of-00001.parquet:   0%|          | 0.00/35.7k [00:00<?, ?B/s]
# pharo_train-00000-of-00001.parquet:   0%|          | 0.00/113k [00:00<?, ?B/s]
# pharo_test-00000-of-00001.parquet:   0%|          | 0.00/30.6k [00:00<?, ?B/s]
# Generating java_train split:   0%|          | 0/7614 [00:00<?, ? examples/s]
# Generating java_test split:   0%|          | 0/1725 [00:00<?, ? examples/s]
# Generating python_train split:   0%|          | 0/1884 [00:00<?, ? examples/s]
# Generating python_test split:   0%|          | 0/406 [00:00<?, ? examples/s]
# Generating pharo_train split:   0%|          | 0/1298 [00:00<?, ? examples/s]
# Generating pharo_test split:   0%|          | 0/289 [00:00<?, ? examples/s]
# Processing languages:   0%|          | 0/6 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/768k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/797k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/298M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/797k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/768k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/298M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to de and back:   0%|          | 0/238 [00:00<?, ?it/s]
# Translating to de and back:   0%|          | 1/238 [00:08<33:43,  8.54s/it]
# Translating to de and back:   1%|          | 2/238 [00:18<36:26,  9.26s/it]
# Translating to de and back:   1%|▏         | 3/238 [00:26<34:10,  8.73s/it]
# Translating to de and back:   2%|▏         | 4/238 [00:38<39:30, 10.13s/it]
# Translating to de and back:   2%|▏         | 5/238 [00:47<37:14,  9.59s/it]
# Translating to de and back:   3%|▎         | 6/238 [00:55<35:22,  9.15s/it]Your input_length: 510 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 510 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 510 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:   3%|▎         | 7/238 [01:27<1:04:25, 16.73s/it]
# Translating to de and back:   3%|▎         | 8/238 [01:34<51:21, 13.40s/it]
# Translating to de and back:   4%|▍         | 9/238 [01:43<45:48, 12.00s/it]
# Translating to de and back:   4%|▍         | 10/238 [01:58<49:07, 12.93s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#
# Translating to de and back:   5%|▍         | 11/238 [02:05<42:52, 11.33s/it]
# Translating to de and back:   5%|▌         | 12/238 [02:14<39:46, 10.56s/it]
# Translating to de and back:   5%|▌         | 13/238 [02:24<38:46, 10.34s/it]
# Translating to de and back:   6%|▌         | 14/238 [02:32<35:59,  9.64s/it]
# Translating to de and back:   6%|▋         | 15/238 [02:40<34:17,  9.22s/it]
# Translating to de and back:   7%|▋         | 16/238 [02:48<32:54,  8.89s/it]
# Translating to de and back:   7%|▋         | 17/238 [02:56<31:24,  8.53s/it]
# Translating to de and back:   8%|▊         | 18/238 [03:04<31:00,  8.46s/it]
# Translating to de and back:   8%|▊         | 19/238 [03:42<1:02:35, 17.15s/it]
# Translating to de and back:   8%|▊         | 20/238 [03:50<52:15, 14.38s/it]
# Translating to de and back:   9%|▉         | 21/238 [03:59<46:28, 12.85s/it]
# Translating to de and back:   9%|▉         | 22/238 [04:09<42:41, 11.86s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  10%|▉         | 23/238 [04:23<45:48, 12.78s/it]
# Translating to de and back:  10%|█         | 24/238 [04:35<43:59, 12.33s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  11%|█         | 25/238 [05:01<58:55, 16.60s/it]
# Translating to de and back:  11%|█         | 26/238 [05:09<49:22, 13.97s/it]
# Translating to de and back:  11%|█▏        | 27/238 [05:19<44:46, 12.73s/it]
# Translating to de and back:  12%|█▏        | 28/238 [05:28<41:09, 11.76s/it]
# Translating to de and back:  12%|█▏        | 29/238 [05:37<37:56, 10.89s/it]
# Translating to de and back:  13%|█▎        | 30/238 [05:44<33:40,  9.72s/it]
# Translating to de and back:  13%|█▎        | 31/238 [05:52<31:40,  9.18s/it]
# Translating to de and back:  13%|█▎        | 32/238 [06:08<38:36, 11.25s/it]
# Translating to de and back:  14%|█▍        | 33/238 [06:17<35:56, 10.52s/it]
# Translating to de and back:  14%|█▍        | 34/238 [06:24<32:22,  9.52s/it]
# Translating to de and back:  15%|█▍        | 35/238 [06:33<31:09,  9.21s/it]
# Translating to de and back:  15%|█▌        | 36/238 [06:47<36:24, 10.81s/it]
# Translating to de and back:  16%|█▌        | 37/238 [06:56<33:33, 10.02s/it]
# Translating to de and back:  16%|█▌        | 38/238 [07:13<40:42, 12.21s/it]
# Translating to de and back:  16%|█▋        | 39/238 [07:20<35:17, 10.64s/it]
# Translating to de and back:  17%|█▋        | 40/238 [07:30<34:15, 10.38s/it]
# Translating to de and back:  17%|█▋        | 41/238 [07:37<30:45,  9.37s/it]
# Translating to de and back:  18%|█▊        | 42/238 [07:44<28:26,  8.70s/it]
# Translating to de and back:  18%|█▊        | 43/238 [07:51<27:08,  8.35s/it]
# Translating to de and back:  18%|█▊        | 44/238 [08:01<28:08,  8.71s/it]
# Translating to de and back:  19%|█▉        | 45/238 [08:21<39:19, 12.22s/it]Your input_length: 510 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 510 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  19%|█▉        | 46/238 [08:47<52:27, 16.39s/it]
# Translating to de and back:  20%|█▉        | 47/238 [08:58<46:49, 14.71s/it]
# Translating to de and back:  20%|██        | 48/238 [09:12<45:47, 14.46s/it]
# Translating to de and back:  21%|██        | 49/238 [09:22<41:45, 13.26s/it]
# Translating to de and back:  21%|██        | 50/238 [09:30<36:24, 11.62s/it]
# Translating to de and back:  21%|██▏       | 51/238 [09:40<34:29, 11.06s/it]Your input_length: 510 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  22%|██▏       | 52/238 [10:31<1:11:32, 23.08s/it]
# Translating to de and back:  22%|██▏       | 53/238 [10:47<1:04:26, 20.90s/it]
# Translating to de and back:  23%|██▎       | 54/238 [11:10<1:06:18, 21.62s/it]
# Translating to de and back:  23%|██▎       | 55/238 [11:20<54:38, 17.92s/it]
# Translating to de and back:  24%|██▎       | 56/238 [11:28<45:26, 14.98s/it]
# Translating to de and back:  24%|██▍       | 57/238 [11:42<44:48, 14.85s/it]
# Translating to de and back:  24%|██▍       | 58/238 [11:54<41:29, 13.83s/it]
# Translating to de and back:  25%|██▍       | 59/238 [12:06<39:55, 13.38s/it]
# Translating to de and back:  25%|██▌       | 60/238 [12:17<37:20, 12.59s/it]
# Translating to de and back:  26%|██▌       | 61/238 [12:24<32:34, 11.04s/it]
# Translating to de and back:  26%|██▌       | 62/238 [12:34<31:08, 10.62s/it]
# Translating to de and back:  26%|██▋       | 63/238 [12:44<30:28, 10.45s/it]
# Translating to de and back:  27%|██▋       | 64/238 [13:01<35:53, 12.37s/it]
# Translating to de and back:  27%|██▋       | 65/238 [13:14<36:11, 12.55s/it]
# Translating to de and back:  28%|██▊       | 66/238 [13:23<33:01, 11.52s/it]
# Translating to de and back:  28%|██▊       | 67/238 [13:31<29:56, 10.51s/it]
# Translating to de and back:  29%|██▊       | 68/238 [13:44<31:53, 11.26s/it]
# Translating to de and back:  29%|██▉       | 69/238 [13:59<34:50, 12.37s/it]
# Translating to de and back:  29%|██▉       | 70/238 [14:13<36:10, 12.92s/it]
# Translating to de and back:  30%|██▉       | 71/238 [14:23<33:45, 12.13s/it]Your input_length: 512 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  30%|███       | 72/238 [14:36<33:41, 12.18s/it]
# Translating to de and back:  31%|███       | 73/238 [14:47<32:51, 11.95s/it]
# Translating to de and back:  31%|███       | 74/238 [15:00<33:13, 12.15s/it]
# Translating to de and back:  32%|███▏      | 75/238 [15:08<30:13, 11.12s/it]
# Translating to de and back:  32%|███▏      | 76/238 [15:20<30:30, 11.30s/it]
# Translating to de and back:  32%|███▏      | 77/238 [15:29<28:28, 10.61s/it]
# Translating to de and back:  33%|███▎      | 78/238 [15:39<27:51, 10.45s/it]
# Translating to de and back:  33%|███▎      | 79/238 [15:50<27:55, 10.54s/it]
# Translating to de and back:  34%|███▎      | 80/238 [16:00<27:00, 10.26s/it]
# Translating to de and back:  34%|███▍      | 81/238 [16:08<25:17,  9.66s/it]
# Translating to de and back:  34%|███▍      | 82/238 [16:17<24:50,  9.56s/it]
# Translating to de and back:  35%|███▍      | 83/238 [16:28<26:01, 10.07s/it]
# Translating to de and back:  35%|███▌      | 84/238 [16:42<28:13, 10.99s/it]
# Translating to de and back:  36%|███▌      | 85/238 [16:52<27:30, 10.79s/it]
# Translating to de and back:  36%|███▌      | 86/238 [17:05<28:59, 11.44s/it]
# Translating to de and back:  37%|███▋      | 87/238 [17:13<26:34, 10.56s/it]
# Translating to de and back:  37%|███▋      | 88/238 [17:24<26:32, 10.61s/it]Your input_length: 488 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  37%|███▋      | 89/238 [17:38<28:44, 11.58s/it]
# Translating to de and back:  38%|███▊      | 90/238 [17:47<26:29, 10.74s/it]
# Translating to de and back:  38%|███▊      | 91/238 [17:54<23:54,  9.76s/it]
# Translating to de and back:  39%|███▊      | 92/238 [18:03<22:43,  9.34s/it]Your input_length: 488 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  39%|███▉      | 93/238 [18:14<24:15, 10.04s/it]
# Translating to de and back:  39%|███▉      | 94/238 [18:23<22:53,  9.54s/it]
# Translating to de and back:  40%|███▉      | 95/238 [18:31<21:38,  9.08s/it]
# Translating to de and back:  40%|████      | 96/238 [18:40<21:48,  9.21s/it]
# Translating to de and back:  41%|████      | 97/238 [18:51<23:06,  9.83s/it]
# Translating to de and back:  41%|████      | 98/238 [19:02<23:14,  9.96s/it]
# Translating to de and back:  42%|████▏     | 99/238 [19:14<24:27, 10.56s/it]
# Translating to de and back:  42%|████▏     | 100/238 [19:21<22:07,  9.62s/it]
# Translating to de and back:  42%|████▏     | 101/238 [19:40<28:11, 12.35s/it]
# Translating to de and back:  43%|████▎     | 102/238 [19:48<25:07, 11.09s/it]
# Translating to de and back:  43%|████▎     | 103/238 [19:57<23:53, 10.62s/it]
# Translating to de and back:  44%|████▎     | 104/238 [20:10<25:05, 11.23s/it]
# Translating to de and back:  44%|████▍     | 105/238 [20:22<25:01, 11.29s/it]
# Translating to de and back:  45%|████▍     | 106/238 [20:41<30:25, 13.83s/it]
# Translating to de and back:  45%|████▍     | 107/238 [20:54<29:26, 13.48s/it]
# Translating to de and back:  45%|████▌     | 108/238 [21:10<30:43, 14.18s/it]
# Translating to de and back:  46%|████▌     | 109/238 [21:23<29:59, 13.95s/it]
# Translating to de and back:  46%|████▌     | 110/238 [21:35<28:11, 13.22s/it]
# Translating to de and back:  47%|████▋     | 111/238 [21:48<27:58, 13.22s/it]
# Translating to de and back:  47%|████▋     | 112/238 [21:59<26:17, 12.52s/it]
# Translating to de and back:  47%|████▋     | 113/238 [22:12<26:11, 12.57s/it]
# Translating to de and back:  48%|████▊     | 114/238 [22:21<24:03, 11.64s/it]
# Translating to de and back:  48%|████▊     | 115/238 [22:31<23:04, 11.25s/it]
# Translating to de and back:  49%|████▊     | 116/238 [22:47<25:48, 12.70s/it]
# Translating to de and back:  49%|████▉     | 117/238 [23:06<28:59, 14.38s/it]
# Translating to de and back:  50%|████▉     | 118/238 [23:14<25:18, 12.65s/it]
# Translating to de and back:  50%|█████     | 119/238 [23:27<24:56, 12.58s/it]
# Translating to de and back:  50%|█████     | 120/238 [23:40<25:16, 12.85s/it]
# Translating to de and back:  51%|█████     | 121/238 [23:50<23:03, 11.82s/it]
# Translating to de and back:  51%|█████▏    | 122/238 [24:03<23:34, 12.20s/it]
# Translating to de and back:  52%|█████▏    | 123/238 [24:15<23:32, 12.28s/it]
# Translating to de and back:  52%|█████▏    | 124/238 [24:39<29:58, 15.77s/it]
# Translating to de and back:  53%|█████▎    | 125/238 [24:58<31:31, 16.74s/it]
# Translating to de and back:  53%|█████▎    | 126/238 [25:09<27:53, 14.94s/it]
# Translating to de and back:  53%|█████▎    | 127/238 [25:18<24:40, 13.34s/it]
# Translating to de and back:  54%|█████▍    | 128/238 [25:35<25:58, 14.17s/it]
# Translating to de and back:  54%|█████▍    | 129/238 [25:45<23:36, 12.99s/it]
# Translating to de and back:  55%|█████▍    | 130/238 [25:56<22:28, 12.49s/it]
# Translating to de and back:  55%|█████▌    | 131/238 [26:07<21:31, 12.07s/it]
# Translating to de and back:  55%|█████▌    | 132/238 [26:18<20:27, 11.58s/it]
# Translating to de and back:  56%|█████▌    | 133/238 [26:28<19:52, 11.36s/it]
# Translating to de and back:  56%|█████▋    | 134/238 [26:47<23:11, 13.38s/it]
# Translating to de and back:  57%|█████▋    | 135/238 [26:57<21:29, 12.52s/it]
# Translating to de and back:  57%|█████▋    | 136/238 [27:06<19:15, 11.33s/it]
# Translating to de and back:  58%|█████▊    | 137/238 [27:16<18:22, 10.92s/it]
# Translating to de and back:  58%|█████▊    | 138/238 [27:29<19:30, 11.70s/it]
# Translating to de and back:  58%|█████▊    | 139/238 [27:39<18:29, 11.20s/it]
# Translating to de and back:  59%|█████▉    | 140/238 [27:54<20:08, 12.33s/it]
# Translating to de and back:  59%|█████▉    | 141/238 [28:07<20:21, 12.59s/it]
# Translating to de and back:  60%|█████▉    | 142/238 [28:24<22:16, 13.92s/it]
# Translating to de and back:  60%|██████    | 143/238 [28:36<21:04, 13.31s/it]
# Translating to de and back:  61%|██████    | 144/238 [28:46<19:13, 12.28s/it]
# Translating to de and back:  61%|██████    | 145/238 [28:55<17:34, 11.33s/it]
# Translating to de and back:  61%|██████▏   | 146/238 [29:08<17:55, 11.69s/it]
# Translating to de and back:  62%|██████▏   | 147/238 [29:15<15:54, 10.48s/it]
# Translating to de and back:  62%|██████▏   | 148/238 [29:25<15:09, 10.11s/it]
# Translating to de and back:  63%|██████▎   | 149/238 [29:45<19:28, 13.13s/it]
# Translating to de and back:  63%|██████▎   | 150/238 [29:55<18:04, 12.32s/it]
# Translating to de and back:  63%|██████▎   | 151/238 [30:03<16:00, 11.04s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  64%|██████▍   | 152/238 [31:45<54:56, 38.33s/it]
# Translating to de and back:  64%|██████▍   | 153/238 [31:57<43:02, 30.38s/it]
# Translating to de and back:  65%|██████▍   | 154/238 [32:12<36:10, 25.84s/it]
# Translating to de and back:  65%|██████▌   | 155/238 [32:27<30:58, 22.39s/it]
# Translating to de and back:  66%|██████▌   | 156/238 [32:36<25:11, 18.44s/it]
# Translating to de and back:  66%|██████▌   | 157/238 [32:45<21:15, 15.74s/it]
# Translating to de and back:  66%|██████▋   | 158/238 [32:54<18:19, 13.74s/it]
# Translating to de and back:  67%|██████▋   | 159/238 [33:05<16:48, 12.77s/it]
# Translating to de and back:  67%|██████▋   | 160/238 [33:17<16:06, 12.39s/it]
# Translating to de and back:  68%|██████▊   | 161/238 [33:26<14:44, 11.48s/it]
# Translating to de and back:  68%|██████▊   | 162/238 [33:36<14:04, 11.11s/it]
# Translating to de and back:  68%|██████▊   | 163/238 [33:46<13:27, 10.77s/it]
# Translating to de and back:  69%|██████▉   | 164/238 [33:56<12:56, 10.49s/it]
# Translating to de and back:  69%|██████▉   | 165/238 [34:12<14:38, 12.03s/it]
# Translating to de and back:  70%|██████▉   | 166/238 [34:18<12:19, 10.27s/it]
# Translating to de and back:  70%|███████   | 167/238 [34:29<12:30, 10.57s/it]
# Translating to de and back:  71%|███████   | 168/238 [34:43<13:25, 11.50s/it]
# Translating to de and back:  71%|███████   | 169/238 [35:00<15:08, 13.16s/it]
# Translating to de and back:  71%|███████▏  | 170/238 [35:15<15:42, 13.86s/it]
# Translating to de and back:  72%|███████▏  | 171/238 [35:27<14:37, 13.10s/it]
# Translating to de and back:  72%|███████▏  | 172/238 [35:46<16:37, 15.12s/it]
# Translating to de and back:  73%|███████▎  | 173/238 [35:57<15:05, 13.93s/it]
# Translating to de and back:  73%|███████▎  | 174/238 [36:17<16:40, 15.63s/it]
# Translating to de and back:  74%|███████▎  | 175/238 [36:44<19:52, 18.94s/it]
# Translating to de and back:  74%|███████▍  | 176/238 [36:57<17:57, 17.38s/it]
# Translating to de and back:  74%|███████▍  | 177/238 [37:08<15:35, 15.33s/it]
# Translating to de and back:  75%|███████▍  | 178/238 [37:20<14:21, 14.35s/it]
# Translating to de and back:  75%|███████▌  | 179/238 [37:33<13:40, 13.91s/it]
# Translating to de and back:  76%|███████▌  | 180/238 [37:47<13:28, 13.94s/it]
# Translating to de and back:  76%|███████▌  | 181/238 [38:00<12:57, 13.63s/it]
# Translating to de and back:  76%|███████▋  | 182/238 [38:11<12:05, 12.96s/it]
# Translating to de and back:  77%|███████▋  | 183/238 [38:26<12:15, 13.37s/it]
# Translating to de and back:  77%|███████▋  | 184/238 [38:34<10:44, 11.93s/it]
# Translating to de and back:  78%|███████▊  | 185/238 [38:46<10:23, 11.77s/it]
# Translating to de and back:  78%|███████▊  | 186/238 [38:57<10:10, 11.74s/it]
# Translating to de and back:  79%|███████▊  | 187/238 [39:15<11:25, 13.45s/it]
# Translating to de and back:  79%|███████▉  | 188/238 [39:26<10:40, 12.82s/it]
# Translating to de and back:  79%|███████▉  | 189/238 [39:44<11:42, 14.33s/it]
# Translating to de and back:  80%|███████▉  | 190/238 [39:53<10:17, 12.86s/it]
# Translating to de and back:  80%|████████  | 191/238 [40:09<10:40, 13.63s/it]
# Translating to de and back:  81%|████████  | 192/238 [40:22<10:25, 13.59s/it]
# Translating to de and back:  81%|████████  | 193/238 [40:34<09:41, 12.92s/it]
# Translating to de and back:  82%|████████▏ | 194/238 [40:47<09:35, 13.08s/it]
# Translating to de and back:  82%|████████▏ | 195/238 [40:59<09:10, 12.80s/it]
# Translating to de and back:  82%|████████▏ | 196/238 [41:11<08:41, 12.42s/it]
# Translating to de and back:  83%|████████▎ | 197/238 [41:22<08:13, 12.04s/it]
# Translating to de and back:  83%|████████▎ | 198/238 [41:36<08:26, 12.66s/it]
# Translating to de and back:  84%|████████▎ | 199/238 [41:45<07:33, 11.64s/it]
# Translating to de and back:  84%|████████▍ | 200/238 [41:54<06:52, 10.84s/it]
# Translating to de and back:  84%|████████▍ | 201/238 [42:04<06:29, 10.51s/it]
# Translating to de and back:  85%|████████▍ | 202/238 [42:11<05:43,  9.54s/it]
# Translating to de and back:  85%|████████▌ | 203/238 [42:18<05:09,  8.85s/it]
# Translating to de and back:  86%|████████▌ | 204/238 [42:28<05:02,  8.91s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  86%|████████▌ | 205/238 [43:03<09:18, 16.94s/it]
# Translating to de and back:  87%|████████▋ | 206/238 [43:13<07:53, 14.78s/it]
# Translating to de and back:  87%|████████▋ | 207/238 [43:26<07:23, 14.31s/it]
# Translating to de and back:  87%|████████▋ | 208/238 [43:37<06:39, 13.33s/it]
# Translating to de and back:  88%|████████▊ | 209/238 [43:51<06:28, 13.38s/it]
# Translating to de and back:  88%|████████▊ | 210/238 [44:02<05:53, 12.63s/it]
# Translating to de and back:  89%|████████▊ | 211/238 [44:13<05:33, 12.37s/it]
# Translating to de and back:  89%|████████▉ | 212/238 [44:26<05:26, 12.55s/it]
# Translating to de and back:  89%|████████▉ | 213/238 [44:33<04:32, 10.90s/it]
# Translating to de and back:  90%|████████▉ | 214/238 [44:44<04:18, 10.77s/it]
# Translating to de and back:  90%|█████████ | 215/238 [44:56<04:16, 11.15s/it]
# Translating to de and back:  91%|█████████ | 216/238 [45:06<04:01, 10.96s/it]
# Translating to de and back:  91%|█████████ | 217/238 [45:17<03:47, 10.82s/it]
# Translating to de and back:  92%|█████████▏| 218/238 [45:32<04:01, 12.08s/it]
# Translating to de and back:  92%|█████████▏| 219/238 [45:46<04:00, 12.65s/it]
# Translating to de and back:  92%|█████████▏| 220/238 [45:56<03:31, 11.76s/it]
# Translating to de and back:  93%|█████████▎| 221/238 [46:03<02:58, 10.52s/it]
# Translating to de and back:  93%|█████████▎| 222/238 [46:16<03:00, 11.30s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  94%|█████████▎| 223/238 [47:34<07:48, 31.24s/it]
# Translating to de and back:  94%|█████████▍| 224/238 [47:46<05:57, 25.51s/it]
# Translating to de and back:  95%|█████████▍| 225/238 [48:00<04:44, 21.89s/it]
# Translating to de and back:  95%|█████████▍| 226/238 [48:12<03:48, 19.01s/it]
# Translating to de and back:  95%|█████████▌| 227/238 [48:24<03:05, 16.83s/it]
# Translating to de and back:  96%|█████████▌| 228/238 [48:31<02:19, 13.92s/it]
# Translating to de and back:  96%|█████████▌| 229/238 [48:41<01:55, 12.83s/it]
# Translating to de and back:  97%|█████████▋| 230/238 [48:49<01:30, 11.31s/it]
# Translating to de and back:  97%|█████████▋| 231/238 [49:00<01:18, 11.18s/it]
# Translating to de and back:  97%|█████████▋| 232/238 [49:09<01:03, 10.52s/it]
# Translating to de and back:  98%|█████████▊| 233/238 [49:19<00:51, 10.31s/it]
# Translating to de and back:  98%|█████████▊| 234/238 [49:27<00:39,  9.87s/it]
# Translating to de and back:  99%|█████████▊| 235/238 [49:36<00:28,  9.50s/it]
# Translating to de and back:  99%|█████████▉| 236/238 [49:48<00:20, 10.37s/it]
# Translating to de and back: 100%|█████████▉| 237/238 [50:03<00:11, 11.72s/it]
# Translating to de and back: 100%|██████████| 238/238 [50:21<00:00, 12.69s/it]
# Processing languages:  17%|█▋        | 1/6 [50:32<4:12:43, 3032.67s/it]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to fr and back:   0%|          | 0/238 [00:00<?, ?it/s]
# Translating to fr and back:   0%|          | 1/238 [00:07<29:49,  7.55s/it]
# Translating to fr and back:   1%|          | 2/238 [00:17<36:04,  9.17s/it]
# Translating to fr and back:   1%|▏         | 3/238 [00:26<34:22,  8.78s/it]
# Translating to fr and back:   2%|▏         | 4/238 [00:34<32:53,  8.43s/it]
# Translating to fr and back:   2%|▏         | 5/238 [00:42<32:27,  8.36s/it]
# Translating to fr and back:   3%|▎         | 6/238 [00:50<31:44,  8.21s/it]
# Translating to fr and back:   3%|▎         | 7/238 [00:58<32:00,  8.31s/it]
# Translating to fr and back:   3%|▎         | 8/238 [01:04<29:12,  7.62s/it]
# Translating to fr and back:   4%|▍         | 9/238 [01:13<30:27,  7.98s/it]
# Translating to fr and back:   4%|▍         | 10/238 [01:21<29:49,  7.85s/it]
# Translating to fr and back:   5%|▍         | 11/238 [01:28<29:32,  7.81s/it]
# Translating to fr and back:   5%|▌         | 12/238 [01:37<30:25,  8.08s/it]
# Translating to fr and back:   5%|▌         | 13/238 [01:46<31:40,  8.45s/it]
# Translating to fr and back:   6%|▌         | 14/238 [01:54<30:09,  8.08s/it]
# Translating to fr and back:   6%|▋         | 15/238 [02:02<30:13,  8.13s/it]
# Translating to fr and back:   7%|▋         | 16/238 [02:10<30:05,  8.13s/it]
# Translating to fr and back:   7%|▋         | 17/238 [02:17<29:09,  7.92s/it]
# Translating to fr and back:   8%|▊         | 18/238 [02:26<29:24,  8.02s/it]
# Translating to fr and back:   8%|▊         | 19/238 [02:33<28:52,  7.91s/it]
# Translating to fr and back:   8%|▊         | 20/238 [02:41<28:33,  7.86s/it]
# Translating to fr and back:   9%|▉         | 21/238 [02:50<29:41,  8.21s/it]
# Translating to fr and back:   9%|▉         | 22/238 [02:59<30:46,  8.55s/it]
# Translating to fr and back:  10%|▉         | 23/238 [03:06<28:59,  8.09s/it]
# Translating to fr and back:  10%|█         | 24/238 [03:17<31:37,  8.86s/it]
# Translating to fr and back:  11%|█         | 25/238 [03:25<30:17,  8.53s/it]
# Translating to fr and back:  11%|█         | 26/238 [03:33<29:18,  8.29s/it]
# Translating to fr and back:  11%|█▏        | 27/238 [03:42<30:10,  8.58s/it]
# Translating to fr and back:  12%|█▏        | 28/238 [03:51<30:25,  8.69s/it]
# Translating to fr and back:  12%|█▏        | 29/238 [04:00<30:28,  8.75s/it]
# Translating to fr and back:  13%|█▎        | 30/238 [04:09<31:01,  8.95s/it]
# Translating to fr and back:  13%|█▎        | 31/238 [04:17<29:22,  8.52s/it]
# Translating to fr and back:  13%|█▎        | 32/238 [04:27<31:05,  9.06s/it]
# Translating to fr and back:  14%|█▍        | 33/238 [04:36<30:36,  8.96s/it]
# Translating to fr and back:  14%|█▍        | 34/238 [04:45<30:47,  9.05s/it]
# Translating to fr and back:  15%|█▍        | 35/238 [04:53<29:51,  8.83s/it]
# Translating to fr and back:  15%|█▌        | 36/238 [05:02<29:47,  8.85s/it]
# Translating to fr and back:  16%|█▌        | 37/238 [05:10<28:44,  8.58s/it]
# Translating to fr and back:  16%|█▌        | 38/238 [05:19<29:16,  8.78s/it]
# Translating to fr and back:  16%|█▋        | 39/238 [05:26<26:56,  8.13s/it]
# Translating to fr and back:  17%|█▋        | 40/238 [05:33<26:09,  7.93s/it]
# Translating to fr and back:  17%|█▋        | 41/238 [05:40<25:01,  7.62s/it]
# Translating to fr and back:  18%|█▊        | 42/238 [05:47<24:17,  7.44s/it]
# Translating to fr and back:  18%|█▊        | 43/238 [05:55<24:28,  7.53s/it]
# Translating to fr and back:  18%|█▊        | 44/238 [06:04<25:53,  8.01s/it]
# Translating to fr and back:  19%|█▉        | 45/238 [06:24<37:31, 11.66s/it]
# Translating to fr and back:  19%|█▉        | 46/238 [06:35<36:11, 11.31s/it]
# Translating to fr and back:  20%|█▉        | 47/238 [06:47<36:18, 11.41s/it]
# Translating to fr and back:  20%|██        | 48/238 [07:00<38:15, 12.08s/it]
# Translating to fr and back:  21%|██        | 49/238 [07:10<36:10, 11.48s/it]
# Translating to fr and back:  21%|██        | 50/238 [07:18<32:35, 10.40s/it]
# Translating to fr and back:  21%|██▏       | 51/238 [07:28<31:57, 10.25s/it]
# Translating to fr and back:  22%|██▏       | 52/238 [07:38<31:30, 10.16s/it]
# Translating to fr and back:  22%|██▏       | 53/238 [07:54<37:02, 12.01s/it]
# Translating to fr and back:  23%|██▎       | 54/238 [08:17<47:02, 15.34s/it]
# Translating to fr and back:  23%|██▎       | 55/238 [08:27<41:19, 13.55s/it]
# Translating to fr and back:  24%|██▎       | 56/238 [08:35<36:17, 11.96s/it]
# Translating to fr and back:  24%|██▍       | 57/238 [08:50<38:37, 12.81s/it]
# Translating to fr and back:  24%|██▍       | 58/238 [09:01<37:01, 12.34s/it]
# Translating to fr and back:  25%|██▍       | 59/238 [09:13<36:49, 12.34s/it]
# Translating to fr and back:  25%|██▌       | 60/238 [09:24<35:22, 11.92s/it]
# Translating to fr and back:  26%|██▌       | 61/238 [09:31<30:44, 10.42s/it]
# Translating to fr and back:  26%|██▌       | 62/238 [09:41<29:36, 10.09s/it]
# Translating to fr and back:  26%|██▋       | 63/238 [09:50<28:55,  9.92s/it]
# Translating to fr and back:  27%|██▋       | 64/238 [10:06<34:05, 11.75s/it]
# Translating to fr and back:  27%|██▋       | 65/238 [10:19<34:42, 12.04s/it]
# Translating to fr and back:  28%|██▊       | 66/238 [10:28<32:11, 11.23s/it]
# Translating to fr and back:  28%|██▊       | 67/238 [10:37<29:33, 10.37s/it]
# Translating to fr and back:  29%|██▊       | 68/238 [10:49<31:17, 11.05s/it]
# Translating to fr and back:  29%|██▉       | 69/238 [11:04<34:16, 12.17s/it]
# Translating to fr and back:  29%|██▉       | 70/238 [11:17<34:34, 12.35s/it]
# Translating to fr and back:  30%|██▉       | 71/238 [11:27<32:32, 11.69s/it]Your input_length: 512 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to fr and back:  30%|███       | 72/238 [11:42<35:21, 12.78s/it]
# Translating to fr and back:  31%|███       | 73/238 [11:54<34:12, 12.44s/it]
# Translating to fr and back:  31%|███       | 74/238 [12:07<34:17, 12.55s/it]
# Translating to fr and back:  32%|███▏      | 75/238 [12:15<30:58, 11.40s/it]
# Translating to fr and back:  32%|███▏      | 76/238 [12:28<31:20, 11.61s/it]
# Translating to fr and back:  32%|███▏      | 77/238 [12:37<29:18, 10.92s/it]
# Translating to fr and back:  33%|███▎      | 78/238 [12:47<28:26, 10.67s/it]
# Translating to fr and back:  33%|███▎      | 79/238 [12:58<28:18, 10.68s/it]
# Translating to fr and back:  34%|███▎      | 80/238 [13:07<27:16, 10.36s/it]
# Translating to fr and back:  34%|███▍      | 81/238 [13:15<25:21,  9.69s/it]
# Translating to fr and back:  34%|███▍      | 82/238 [13:25<25:10,  9.68s/it]
# Translating to fr and back:  35%|███▍      | 83/238 [13:37<26:28, 10.25s/it]
# Translating to fr and back:  35%|███▌      | 84/238 [13:50<28:37, 11.15s/it]
# Translating to fr and back:  36%|███▌      | 85/238 [14:00<27:40, 10.85s/it]
# Translating to fr and back:  36%|███▌      | 86/238 [14:13<29:18, 11.57s/it]
# Translating to fr and back:  37%|███▋      | 87/238 [14:21<25:58, 10.32s/it]
# Translating to fr and back:  37%|███▋      | 88/238 [14:31<25:33, 10.23s/it]Your input_length: 490 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to fr and back:  37%|███▋      | 89/238 [14:45<28:23, 11.43s/it]
# Translating to fr and back:  38%|███▊      | 90/238 [14:54<26:11, 10.62s/it]
# Translating to fr and back:  38%|███▊      | 91/238 [15:01<23:51,  9.74s/it]
# Translating to fr and back:  39%|███▊      | 92/238 [15:11<23:27,  9.64s/it]Your input_length: 490 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to fr and back:  39%|███▉      | 93/238 [15:23<24:50, 10.28s/it]
# Translating to fr and back:  39%|███▉      | 94/238 [15:31<23:14,  9.68s/it]
# Translating to fr and back:  40%|███▉      | 95/238 [15:39<22:19,  9.37s/it]
# Translating to fr and back:  40%|████      | 96/238 [15:50<22:41,  9.59s/it]
# Translating to fr and back:  41%|████      | 97/238 [16:01<24:08, 10.28s/it]
# Translating to fr and back:  41%|████      | 98/238 [16:11<23:44, 10.18s/it]
# Translating to fr and back:  42%|████▏     | 99/238 [16:23<24:55, 10.76s/it]
# Translating to fr and back:  42%|████▏     | 100/238 [16:31<22:39,  9.85s/it]
# Translating to fr and back:  42%|████▏     | 101/238 [16:50<28:43, 12.58s/it]
# Translating to fr and back:  43%|████▎     | 102/238 [16:58<25:24, 11.21s/it]
# Translating to fr and back:  43%|████▎     | 103/238 [17:07<23:51, 10.61s/it]
# Translating to fr and back:  44%|████▎     | 104/238 [17:21<25:29, 11.41s/it]
# Translating to fr and back:  44%|████▍     | 105/238 [17:32<25:31, 11.52s/it]
# Translating to fr and back:  45%|████▍     | 106/238 [17:51<30:11, 13.72s/it]
# Translating to fr and back:  45%|████▍     | 107/238 [18:04<29:12, 13.38s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to fr and back:  45%|████▌     | 108/238 [18:25<33:59, 15.69s/it]
# Translating to fr and back:  46%|████▌     | 109/238 [18:42<34:39, 16.12s/it]
# Translating to fr and back:  46%|████▌     | 110/238 [18:54<31:39, 14.84s/it]
# Translating to fr and back:  47%|████▋     | 111/238 [19:07<30:14, 14.29s/it]
# Translating to fr and back:  47%|████▋     | 112/238 [19:17<27:30, 13.10s/it]
# Translating to fr and back:  47%|████▋     | 113/238 [19:30<27:01, 12.97s/it]
# Translating to fr and back:  48%|████▊     | 114/238 [19:39<24:30, 11.86s/it]
# Translating to fr and back:  48%|████▊     | 115/238 [19:50<23:28, 11.45s/it]
# Translating to fr and back:  49%|████▊     | 116/238 [20:06<26:07, 12.85s/it]
# Translating to fr and back:  49%|████▉     | 117/238 [20:25<29:43, 14.74s/it]
# Translating to fr and back:  50%|████▉     | 118/238 [20:34<25:48, 12.91s/it]
# Translating to fr and back:  50%|█████     | 119/238 [20:46<25:19, 12.77s/it]
# Translating to fr and back:  50%|█████     | 120/238 [20:59<25:22, 12.90s/it]
# Translating to fr and back:  51%|█████     | 121/238 [21:09<23:06, 11.85s/it]
# Translating to fr and back:  51%|█████▏    | 122/238 [21:22<24:02, 12.44s/it]
# Translating to fr and back:  52%|█████▏    | 123/238 [21:35<23:48, 12.42s/it]
# Translating to fr and back:  52%|█████▏    | 124/238 [21:48<24:04, 12.67s/it]
# Translating to fr and back:  53%|█████▎    | 125/238 [22:07<27:15, 14.47s/it]
# Translating to fr and back:  53%|█████▎    | 126/238 [22:18<25:10, 13.49s/it]
# Translating to fr and back:  53%|█████▎    | 127/238 [22:28<22:58, 12.42s/it]
# Translating to fr and back:  54%|█████▍    | 128/238 [22:44<24:51, 13.56s/it]
# Translating to fr and back:  54%|█████▍    | 129/238 [22:54<22:51, 12.58s/it]
# Translating to fr and back:  55%|█████▍    | 130/238 [23:06<22:13, 12.35s/it]
# Translating to fr and back:  55%|█████▌    | 131/238 [23:18<21:29, 12.05s/it]
# Translating to fr and back:  55%|█████▌    | 132/238 [23:28<20:34, 11.65s/it]
# Translating to fr and back:  56%|█████▌    | 133/238 [23:40<20:12, 11.55s/it]
# Translating to fr and back:  56%|█████▋    | 134/238 [23:59<23:51, 13.77s/it]
# Translating to fr and back:  57%|█████▋    | 135/238 [24:09<21:47, 12.69s/it]
# Translating to fr and back:  57%|█████▋    | 136/238 [24:17<19:29, 11.47s/it]
# Translating to fr and back:  58%|█████▊    | 137/238 [24:27<18:33, 11.03s/it]
# Translating to fr and back:  58%|█████▊    | 138/238 [24:41<19:37, 11.78s/it]
# Translating to fr and back:  58%|█████▊    | 139/238 [24:52<18:53, 11.45s/it]
# Translating to fr and back:  59%|█████▉    | 140/238 [25:09<21:37, 13.24s/it]
# Translating to fr and back:  59%|█████▉    | 141/238 [25:22<21:30, 13.30s/it]
# Translating to fr and back:  60%|█████▉    | 142/238 [25:40<23:25, 14.64s/it]
# Translating to fr and back:  60%|██████    | 143/238 [25:51<21:33, 13.62s/it]
# Translating to fr and back:  61%|██████    | 144/238 [26:02<19:43, 12.59s/it]
# Translating to fr and back:  61%|██████    | 145/238 [26:11<17:48, 11.49s/it]
# Translating to fr and back:  61%|██████▏   | 146/238 [26:23<18:00, 11.74s/it]
# Translating to fr and back:  62%|██████▏   | 147/238 [26:30<15:50, 10.45s/it]
# Translating to fr and back:  62%|██████▏   | 148/238 [26:39<14:50,  9.89s/it]
# Translating to fr and back:  63%|██████▎   | 149/238 [26:59<19:04, 12.85s/it]
# Translating to fr and back:  63%|██████▎   | 150/238 [27:09<17:57, 12.24s/it]
# Translating to fr and back:  63%|██████▎   | 151/238 [27:18<16:05, 11.10s/it]
# Translating to fr and back:  64%|██████▍   | 152/238 [27:27<15:00, 10.47s/it]
# Translating to fr and back:  64%|██████▍   | 153/238 [27:39<15:35, 11.00s/it]
# Translating to fr and back:  65%|██████▍   | 154/238 [27:54<17:07, 12.23s/it]
# Translating to fr and back:  65%|██████▌   | 155/238 [28:09<17:48, 12.88s/it]
# Translating to fr and back:  66%|██████▌   | 156/238 [28:17<15:57, 11.67s/it]
# Translating to fr and back:  66%|██████▌   | 157/238 [28:27<15:05, 11.18s/it]
# Translating to fr and back:  66%|██████▋   | 158/238 [28:37<14:04, 10.55s/it]
# Translating to fr and back:  67%|██████▋   | 159/238 [28:47<13:40, 10.38s/it]
# Translating to fr and back:  67%|██████▋   | 160/238 [28:57<13:39, 10.50s/it]
# Translating to fr and back:  68%|██████▊   | 161/238 [29:07<13:00, 10.13s/it]
# Translating to fr and back:  68%|██████▊   | 162/238 [29:17<12:52, 10.16s/it]
# Translating to fr and back:  68%|██████▊   | 163/238 [29:27<12:50, 10.27s/it]
# Translating to fr and back:  69%|██████▉   | 164/238 [29:37<12:36, 10.22s/it]
# Translating to fr and back:  69%|██████▉   | 165/238 [29:53<14:32, 11.95s/it]
# Translating to fr and back:  70%|██████▉   | 166/238 [29:59<12:04, 10.06s/it]
# Translating to fr and back:  70%|███████   | 167/238 [30:10<12:03, 10.19s/it]
# Translating to fr and back:  71%|███████   | 168/238 [30:19<11:43, 10.05s/it]
# Translating to fr and back:  71%|███████   | 169/238 [30:40<15:15, 13.27s/it]
# Translating to fr and back:  71%|███████▏  | 170/238 [30:55<15:34, 13.74s/it]
# Translating to fr and back:  72%|███████▏  | 171/238 [31:06<14:27, 12.95s/it]
# Translating to fr and back:  72%|███████▏  | 172/238 [31:26<16:28, 14.98s/it]
# Translating to fr and back:  73%|███████▎  | 173/238 [31:37<14:55, 13.78s/it]
# Translating to fr and back:  73%|███████▎  | 174/238 [31:56<16:31, 15.49s/it]
# Translating to fr and back:  74%|███████▎  | 175/238 [32:24<20:04, 19.13s/it]
# Translating to fr and back:  74%|███████▍  | 176/238 [32:38<18:04, 17.49s/it]
# Translating to fr and back:  74%|███████▍  | 177/238 [32:48<15:40, 15.42s/it]
# Translating to fr and back:  75%|███████▍  | 178/238 [33:00<14:17, 14.29s/it]
# Translating to fr and back:  75%|███████▌  | 179/238 [33:09<12:29, 12.70s/it]
# Translating to fr and back:  76%|███████▌  | 180/238 [33:23<12:44, 13.17s/it]
# Translating to fr and back:  76%|███████▌  | 181/238 [33:37<12:43, 13.40s/it]
# Translating to fr and back:  76%|███████▋  | 182/238 [33:49<12:00, 12.86s/it]
# Translating to fr and back:  77%|███████▋  | 183/238 [33:59<11:04, 12.07s/it]
# Translating to fr and back:  77%|███████▋  | 184/238 [34:07<09:55, 11.03s/it]
# Translating to fr and back:  78%|███████▊  | 185/238 [34:18<09:44, 11.03s/it]
# Translating to fr and back:  78%|███████▊  | 186/238 [34:30<09:38, 11.13s/it]
# Translating to fr and back:  79%|███████▊  | 187/238 [34:46<10:48, 12.72s/it]
# Translating to fr and back:  79%|███████▉  | 188/238 [34:57<10:11, 12.24s/it]
# Translating to fr and back:  79%|███████▉  | 189/238 [35:15<11:13, 13.75s/it]
# Translating to fr and back:  80%|███████▉  | 190/238 [35:24<10:00, 12.50s/it]
# Translating to fr and back:  80%|████████  | 191/238 [35:40<10:35, 13.52s/it]
# Translating to fr and back:  81%|████████  | 192/238 [35:54<10:20, 13.48s/it]
# Translating to fr and back:  81%|████████  | 193/238 [36:05<09:34, 12.77s/it]
# Translating to fr and back:  82%|████████▏ | 194/238 [36:19<09:38, 13.16s/it]
# Translating to fr and back:  82%|████████▏ | 195/238 [36:31<09:14, 12.89s/it]
# Translating to fr and back:  82%|████████▏ | 196/238 [36:42<08:42, 12.45s/it]
# Translating to fr and back:  83%|████████▎ | 197/238 [36:53<08:08, 11.93s/it]
# Translating to fr and back:  83%|████████▎ | 198/238 [37:07<08:23, 12.60s/it]
# Translating to fr and back:  84%|████████▎ | 199/238 [37:17<07:32, 11.60s/it]
# Translating to fr and back:  84%|████████▍ | 200/238 [37:26<06:52, 10.86s/it]
# Translating to fr and back:  84%|████████▍ | 201/238 [37:35<06:28, 10.50s/it]
# Translating to fr and back:  85%|████████▍ | 202/238 [37:42<05:39,  9.44s/it]
# Translating to fr and back:  85%|████████▌ | 203/238 [37:49<05:06,  8.77s/it]
# Translating to fr and back:  86%|████████▌ | 204/238 [37:58<04:58,  8.79s/it]
# Translating to fr and back:  86%|████████▌ | 205/238 [38:13<05:45, 10.47s/it]
# Translating to fr and back:  87%|████████▋ | 206/238 [38:22<05:28, 10.26s/it]
# Translating to fr and back:  87%|████████▋ | 207/238 [38:35<05:37, 10.90s/it]
# Translating to fr and back:  87%|████████▋ | 208/238 [38:46<05:32, 11.08s/it]
# Translating to fr and back:  88%|████████▊ | 209/238 [38:56<05:06, 10.58s/it]
# Translating to fr and back:  88%|████████▊ | 210/238 [39:07<04:59, 10.69s/it]
# Translating to fr and back:  89%|████████▊ | 211/238 [39:19<04:59, 11.09s/it]
# Translating to fr and back:  89%|████████▉ | 212/238 [39:32<05:03, 11.69s/it]
# Translating to fr and back:  89%|████████▉ | 213/238 [39:39<04:15, 10.24s/it]
# Translating to fr and back:  90%|████████▉ | 214/238 [39:49<04:03, 10.14s/it]
# Translating to fr and back:  90%|█████████ | 215/238 [40:00<04:01, 10.52s/it]
# Translating to fr and back:  91%|█████████ | 216/238 [40:10<03:48, 10.40s/it]
# Translating to fr and back:  91%|█████████ | 217/238 [40:20<03:37, 10.36s/it]
# Translating to fr and back:  92%|█████████▏| 218/238 [40:36<03:55, 11.79s/it]
# Translating to fr and back:  92%|█████████▏| 219/238 [40:49<03:54, 12.33s/it]
# Translating to fr and back:  92%|█████████▏| 220/238 [40:59<03:27, 11.52s/it]
# Translating to fr and back:  93%|█████████▎| 221/238 [41:07<02:56, 10.41s/it]
# Translating to fr and back:  93%|█████████▎| 222/238 [41:19<02:57, 11.08s/it]
# Translating to fr and back:  94%|█████████▎| 223/238 [41:28<02:35, 10.35s/it]
# Translating to fr and back:  94%|█████████▍| 224/238 [41:40<02:34, 11.04s/it]
# Translating to fr and back:  95%|█████████▍| 225/238 [41:54<02:32, 11.76s/it]
# Translating to fr and back:  95%|█████████▍| 226/238 [42:06<02:22, 11.87s/it]
# Translating to fr and back:  95%|█████████▌| 227/238 [42:18<02:10, 11.82s/it]
# Translating to fr and back:  96%|█████████▌| 228/238 [42:25<01:45, 10.52s/it]
# Translating to fr and back:  96%|█████████▌| 229/238 [42:36<01:35, 10.59s/it]
# Translating to fr and back:  97%|█████████▋| 230/238 [42:44<01:17,  9.73s/it]
# Translating to fr and back:  97%|█████████▋| 231/238 [42:55<01:11, 10.16s/it]
# Translating to fr and back:  97%|█████████▋| 232/238 [43:04<00:59,  9.86s/it]
# Translating to fr and back:  98%|█████████▊| 233/238 [43:13<00:48,  9.73s/it]
# Translating to fr and back:  98%|█████████▊| 234/238 [43:22<00:37,  9.42s/it]
# Translating to fr and back:  99%|█████████▊| 235/238 [43:31<00:27,  9.31s/it]
# Translating to fr and back:  99%|█████████▉| 236/238 [43:43<00:20, 10.06s/it]
# Translating to fr and back: 100%|█████████▉| 237/238 [43:58<00:11, 11.38s/it]
# Translating to fr and back: 100%|██████████| 238/238 [44:15<00:00, 11.16s/it]
# Processing languages:  33%|███▎      | 2/6 [1:34:59<3:07:50, 2817.53s/it]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/806k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/805k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.62M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/805k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/807k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.62M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to zh and back:   0%|          | 0/238 [00:00<?, ?it/s]
# Translating to zh and back:   0%|          | 1/238 [00:09<38:17,  9.70s/it]
# Translating to zh and back:   1%|          | 2/238 [00:26<54:49, 13.94s/it]
# Translating to zh and back:   1%|▏         | 3/238 [00:35<45:59, 11.74s/it]
# Translating to zh and back:   2%|▏         | 4/238 [00:43<40:16, 10.32s/it]
# Translating to zh and back:   2%|▏         | 5/238 [00:53<39:33, 10.19s/it]
# Translating to zh and back:   3%|▎         | 6/238 [01:02<37:22,  9.67s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# ...
# Translating to ru and back:  21%|██▏       | 51/238 [09:17<33:01, 10.60s/it]
# Translating to ru and back:  22%|██▏       | 52/238 [09:35<39:21, 12.70s/it]
# Translating to ru and back:  22%|██▏       | 53/238 [09:52<43:21, 14.06s/it]Your input_length: 509 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to ru and back:  23%|██▎       | 54/238 [10:13<49:44, 16.22s/it]
# Translating to ru and back:  23%|██▎       | 55/238 [10:23<44:07, 14.47s/it]
# Translating to ru and back:  24%|██▎       | 56/238 [10:32<38:09, 12.58s/it]
# Translating to ru and back:  24%|██▍       | 57/238 [10:49<42:14, 14.00s/it]
# Translating to ru and back:  24%|██▍       | 58/238 [11:01<40:32, 13.51s/it]
# Translating to ru and back:  25%|██▍       | 59/238 [11:15<40:07, 13.45s/it]
# Translating to ru and back:  25%|██▌       | 60/238 [11:25<37:20, 12.59s/it]
# Translating to ru and back:  26%|██▌       | 61/238 [11:33<33:11, 11.25s/it]
# Translating to ru and back:  26%|██▌       | 62/238 [11:43<31:27, 10.72s/it]
# Translating to ru and back:  26%|██▋       | 63/238 [11:54<31:14, 10.71s/it]
# Translating to ru and back:  27%|██▋       | 64/238 [12:10<35:56, 12.39s/it]
# Translating to ru and back:  27%|██▋       | 65/238 [12:24<36:56, 12.81s/it]
# Translating to ru and back:  28%|██▊       | 66/238 [12:32<32:50, 11.46s/it]
# Translating to ru and back:  28%|██▊       | 67/238 [12:41<30:55, 10.85s/it]
# Translating to ru and back:  29%|██▊       | 68/238 [12:54<32:32, 11.48s/it]
# Translating to ru and back:  29%|██▉       | 69/238 [13:09<35:09, 12.48s/it]
# Translating to ru and back:  29%|██▉       | 70/238 [13:23<35:56, 12.84s/it]
# Translating to ru and back:  30%|██▉       | 71/238 [13:34<34:46, 12.49s/it]Your input_length: 512 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to ru and back:  30%|███       | 72/238 [13:52<39:07, 14.14s/it]
# Translating to ru and back:  31%|███       | 73/238 [14:09<41:13, 14.99s/it]
# Translating to ru and back:  31%|███       | 74/238 [14:23<39:48, 14.56s/it]
# Translating to ru and back:  32%|███▏      | 75/238 [14:32<35:10, 12.95s/it]
# Translating to ru and back:  32%|███▏      | 76/238 [14:45<34:44, 12.87s/it]
# Translating to ru and back:  32%|███▏      | 77/238 [14:55<31:58, 11.92s/it]
# Translating to ru and back:  33%|███▎      | 78/238 [15:05<30:24, 11.41s/it]
# Translating to ru and back:  33%|███▎      | 79/238 [15:16<30:25, 11.48s/it]
# Translating to ru and back:  34%|███▎      | 80/238 [15:26<28:45, 10.92s/it]
# Translating to ru and back:  34%|███▍      | 81/238 [15:35<26:55, 10.29s/it]
# Translating to ru and back:  34%|███▍      | 82/238 [15:45<26:29, 10.19s/it]
# Translating to ru and back:  35%|███▍      | 83/238 [15:57<28:05, 10.88s/it]
# Translating to ru and back:  35%|███▌      | 84/238 [16:10<29:19, 11.43s/it]
# Translating to ru and back:  36%|███▌      | 85/238 [16:21<28:51, 11.32s/it]
# Translating to ru and back:  36%|███▌      | 86/238 [16:35<30:30, 12.04s/it]
# Translating to ru and back:  37%|███▋      | 87/238 [16:43<27:02, 10.75s/it]
# Translating to ru and back:  37%|███▋      | 88/238 [16:52<25:47, 10.31s/it]Your input_length: 496 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 494 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to ru and back:  37%|███▋      | 89/238 [17:11<32:14, 12.98s/it]
# Translating to ru and back:  38%|███▊      | 90/238 [17:20<29:13, 11.85s/it]
# Translating to ru and back:  38%|███▊      | 91/238 [17:28<26:01, 10.62s/it]
# Translating to ru and back:  39%|███▊      | 92/238 [17:38<25:09, 10.34s/it]Your input_length: 496 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 494 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to ru and back:  39%|███▉      | 93/238 [17:54<29:40, 12.28s/it]
# Translating to ru and back:  39%|███▉      | 94/238 [18:03<26:50, 11.18s/it]
# Translating to ru and back:  40%|███▉      | 95/238 [18:12<25:07, 10.54s/it]
# Translating to ru and back:  40%|████      | 96/238 [18:23<25:11, 10.64s/it]
# Translating to ru and back:  41%|████      | 97/238 [18:36<26:30, 11.28s/it]
# Translating to ru and back:  41%|████      | 98/238 [18:47<26:17, 11.27s/it]
# Translating to ru and back:  42%|████▏     | 99/238 [19:01<27:37, 11.93s/it]
# Translating to ru and back:  42%|████▏     | 100/238 [19:09<24:54, 10.83s/it]
# Translating to ru and back:  42%|████▏     | 101/238 [19:29<30:59, 13.57s/it]
# Translating to ru and back:  43%|████▎     | 102/238 [19:38<27:29, 12.13s/it]
# Translating to ru and back:  43%|████▎     | 103/238 [19:47<25:35, 11.38s/it]
# Translating to ru and back:  44%|████▎     | 104/238 [20:01<26:49, 12.01s/it]
# Translating to ru and back:  44%|████▍     | 105/238 [20:12<26:20, 11.89s/it]
# Translating to ru and back:  45%|████▍     | 106/238 [20:31<30:35, 13.91s/it]
# Translating to ru and back:  45%|████▍     | 107/238 [20:44<29:57, 13.72s/it]
# Translating to ru and back:  45%|████▌     | 108/238 [21:04<33:58, 15.68s/it]
# Translating to ru and back:  46%|████▌     | 109/238 [21:19<32:53, 15.30s/it]
# Translating to ru and back:  46%|████▌     | 110/238 [21:31<30:25, 14.26s/it]
# Translating to ru and back:  47%|████▋     | 111/238 [21:48<32:05, 15.16s/it]
# Translating to ru and back:  47%|████▋     | 112/238 [22:00<29:39, 14.13s/it]
# Translating to ru and back:  47%|████▋     | 113/238 [22:12<28:34, 13.71s/it]
# Translating to ru and back:  48%|████▊     | 114/238 [22:23<26:31, 12.84s/it]
# Translating to ru and back:  48%|████▊     | 115/238 [22:35<25:27, 12.42s/it]
# Translating to ru and back:  49%|████▊     | 116/238 [22:52<28:21, 13.95s/it]
# Translating to ru and back:  49%|████▉     | 117/238 [23:11<31:10, 15.46s/it]
# Translating to ru and back:  50%|████▉     | 118/238 [23:22<28:03, 14.03s/it]
# Translating to ru and back:  50%|█████     | 119/238 [23:36<27:51, 14.05s/it]
# Translating to ru and back:  50%|█████     | 120/238 [23:50<27:42, 14.09s/it]
# Translating to ru and back:  51%|█████     | 121/238 [24:01<25:23, 13.02s/it]
# Translating to ru and back:  51%|█████▏    | 122/238 [24:15<25:50, 13.37s/it]
# Translating to ru and back:  52%|█████▏    | 123/238 [24:29<25:51, 13.49s/it]
# Translating to ru and back:  52%|█████▏    | 124/238 [24:42<25:28, 13.41s/it]
# Translating to ru and back:  53%|█████▎    | 125/238 [25:00<27:45, 14.74s/it]
# Translating to ru and back:  53%|█████▎    | 126/238 [25:12<26:19, 14.10s/it]
# Translating to ru and back:  53%|█████▎    | 127/238 [25:23<24:03, 13.00s/it]
# Translating to ru and back:  54%|█████▍    | 128/238 [25:42<27:16, 14.88s/it]
# Translating to ru and back:  54%|█████▍    | 129/238 [25:53<24:44, 13.62s/it]
# Translating to ru and back:  55%|█████▍    | 130/238 [26:05<23:59, 13.33s/it]
# Translating to ru and back:  55%|█████▌    | 131/238 [26:16<22:38, 12.70s/it]
# Translating to ru and back:  55%|█████▌    | 132/238 [26:28<21:49, 12.36s/it]
# Translating to ru and back:  56%|█████▌    | 133/238 [26:39<21:01, 12.01s/it]
# Translating to ru and back:  56%|█████▋    | 134/238 [26:58<24:09, 13.93s/it]
# Translating to ru and back:  57%|█████▋    | 135/238 [27:14<25:18, 14.74s/it]
# Translating to ru and back:  57%|█████▋    | 136/238 [27:29<25:17, 14.88s/it]
# Translating to ru and back:  58%|█████▊    | 137/238 [27:39<22:34, 13.41s/it]
# Translating to ru and back:  58%|█████▊    | 138/238 [27:53<22:36, 13.56s/it]
# Translating to ru and back:  58%|█████▊    | 139/238 [28:05<21:31, 13.05s/it]
# Translating to ru and back:  59%|█████▉    | 140/238 [28:20<22:11, 13.58s/it]
# Translating to ru and back:  59%|█████▉    | 141/238 [28:34<22:06, 13.68s/it]
# Translating to ru and back:  60%|█████▉    | 142/238 [28:53<24:15, 15.16s/it]
# Translating to ru and back:  60%|██████    | 143/238 [29:05<22:44, 14.36s/it]
# Translating to ru and back:  61%|██████    | 144/238 [29:16<20:53, 13.33s/it]
# Translating to ru and back:  61%|██████    | 145/238 [29:25<18:31, 11.95s/it]
# Translating to ru and back:  61%|██████▏   | 146/238 [29:40<19:44, 12.87s/it]
# Translating to ru and back:  62%|██████▏   | 147/238 [29:47<17:09, 11.31s/it]
# Translating to ru and back:  62%|██████▏   | 148/238 [29:57<16:02, 10.70s/it]
# Translating to ru and back:  63%|██████▎   | 149/238 [30:20<21:36, 14.57s/it]
# Translating to ru and back:  63%|██████▎   | 150/238 [30:31<19:45, 13.47s/it]
# Translating to ru and back:  63%|██████▎   | 151/238 [30:40<17:39, 12.18s/it]
# Translating to ru and back:  64%|██████▍   | 152/238 [30:50<16:34, 11.56s/it]
# Translating to ru and back:  64%|██████▍   | 153/238 [31:03<16:43, 11.80s/it]
# Translating to ru and back:  65%|██████▍   | 154/238 [31:18<17:58, 12.84s/it]
# Translating to ru and back:  65%|██████▌   | 155/238 [31:33<18:25, 13.32s/it]
# Translating to ru and back:  66%|██████▌   | 156/238 [31:42<16:44, 12.25s/it]
# Translating to ru and back:  66%|██████▌   | 157/238 [31:53<16:00, 11.85s/it]
# Translating to ru and back:  66%|██████▋   | 158/238 [32:03<15:08, 11.36s/it]
# Translating to ru and back:  67%|██████▋   | 159/238 [32:15<14:55, 11.34s/it]
# Translating to ru and back:  67%|██████▋   | 160/238 [32:26<14:42, 11.31s/it]
# Translating to ru and back:  68%|██████▊   | 161/238 [32:36<13:53, 10.82s/it]
# Translating to ru and back:  68%|██████▊   | 162/238 [32:47<13:48, 10.90s/it]
# Translating to ru and back:  68%|██████▊   | 163/238 [32:58<13:48, 11.04s/it]
# Translating to ru and back:  69%|██████▉   | 164/238 [33:09<13:39, 11.08s/it]
# Translating to ru and back:  69%|██████▉   | 165/238 [33:29<16:30, 13.57s/it]
# Translating to ru and back:  70%|██████▉   | 166/238 [33:36<14:04, 11.73s/it]
# Translating to ru and back:  70%|███████   | 167/238 [33:48<13:47, 11.65s/it]
# Translating to ru and back:  71%|███████   | 168/238 [33:58<13:18, 11.40s/it]
# Translating to ru and back:  71%|███████   | 169/238 [34:15<15:04, 13.10s/it]
# Translating to ru and back:  71%|███████▏  | 170/238 [34:30<15:29, 13.67s/it]
# Translating to ru and back:  72%|███████▏  | 171/238 [34:42<14:28, 12.96s/it]
# Translating to ru and back:  72%|███████▏  | 172/238 [35:02<16:37, 15.11s/it]
# Translating to ru and back:  73%|███████▎  | 173/238 [35:14<15:26, 14.26s/it]
# Translating to ru and back:  73%|███████▎  | 174/238 [35:35<17:15, 16.18s/it]
# Translating to ru and back:  74%|███████▎  | 175/238 [36:03<20:46, 19.78s/it]
# Translating to ru and back:  74%|███████▍  | 176/238 [36:17<18:43, 18.12s/it]
# Translating to ru and back:  74%|███████▍  | 177/238 [36:29<16:24, 16.14s/it]
# Translating to ru and back:  75%|███████▍  | 178/238 [36:41<15:02, 15.05s/it]
# Translating to ru and back:  75%|███████▌  | 179/238 [36:51<13:08, 13.37s/it]
# Translating to ru and back:  76%|███████▌  | 180/238 [37:06<13:32, 14.02s/it]
# Translating to ru and back:  76%|███████▌  | 181/238 [37:21<13:36, 14.32s/it]
# Translating to ru and back:  76%|███████▋  | 182/238 [37:34<12:54, 13.83s/it]
# Translating to ru and back:  77%|███████▋  | 183/238 [37:45<11:58, 13.06s/it]
# Translating to ru and back:  77%|███████▋  | 184/238 [37:55<10:44, 11.93s/it]
# Translating to ru and back:  78%|███████▊  | 185/238 [38:07<10:43, 12.14s/it]
# Translating to ru and back:  78%|███████▊  | 186/238 [38:21<11:03, 12.75s/it]
# Translating to ru and back:  79%|███████▊  | 187/238 [38:44<13:15, 15.59s/it]
# Translating to ru and back:  79%|███████▉  | 188/238 [38:57<12:23, 14.86s/it]
# Translating to ru and back:  79%|███████▉  | 189/238 [39:15<12:57, 15.87s/it]
# Translating to ru and back:  80%|███████▉  | 190/238 [39:26<11:26, 14.31s/it]
# Translating to ru and back:  80%|████████  | 191/238 [39:43<11:49, 15.10s/it]
# Translating to ru and back:  81%|████████  | 192/238 [39:56<11:15, 14.69s/it]
# Translating to ru and back:  81%|████████  | 193/238 [40:08<10:23, 13.86s/it]
# Translating to ru and back:  82%|████████▏ | 194/238 [40:23<10:26, 14.23s/it]
# Translating to ru and back:  82%|████████▏ | 195/238 [40:36<09:53, 13.81s/it]
# Translating to ru and back:  82%|████████▏ | 196/238 [40:49<09:27, 13.52s/it]
# Translating to ru and back:  83%|████████▎ | 197/238 [41:00<08:49, 12.93s/it]Your input_length: 506 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to ru and back:  83%|████████▎ | 198/238 [41:20<09:53, 14.84s/it]
# Translating to ru and back:  84%|████████▎ | 199/238 [41:30<08:44, 13.46s/it]
# Translating to ru and back:  84%|████████▍ | 200/238 [41:40<07:51, 12.41s/it]
# Translating to ru and back:  84%|████████▍ | 201/238 [41:51<07:18, 11.86s/it]
# Translating to ru and back:  85%|████████▍ | 202/238 [41:58<06:19, 10.54s/it]
# Translating to ru and back:  85%|████████▌ | 203/238 [42:06<05:41,  9.74s/it]
# Translating to ru and back:  86%|████████▌ | 204/238 [42:16<05:37,  9.92s/it]
# Translating to ru and back:  86%|████████▌ | 205/238 [42:34<06:45, 12.29s/it]
# Translating to ru and back:  87%|████████▋ | 206/238 [42:45<06:19, 11.85s/it]
# Translating to ru and back:  87%|████████▋ | 207/238 [42:59<06:26, 12.46s/it]
# Translating to ru and back:  87%|████████▋ | 208/238 [43:11<06:11, 12.39s/it]
# Translating to ru and back:  88%|████████▊ | 209/238 [43:21<05:38, 11.69s/it]
# Translating to ru and back:  88%|████████▊ | 210/238 [43:33<05:32, 11.89s/it]
# Translating to ru and back:  89%|████████▊ | 211/238 [43:46<05:23, 11.97s/it]
# Translating to ru and back:  89%|████████▉ | 212/238 [44:00<05:30, 12.72s/it]
# Translating to ru and back:  89%|████████▉ | 213/238 [44:09<04:46, 11.45s/it]
# Translating to ru and back:  90%|████████▉ | 214/238 [44:21<04:40, 11.67s/it]
# Translating to ru and back:  90%|█████████ | 215/238 [44:34<04:41, 12.25s/it]
# Translating to ru and back:  91%|█████████ | 216/238 [44:45<04:21, 11.86s/it]
# Translating to ru and back:  91%|█████████ | 217/238 [44:57<04:10, 11.91s/it]
# Translating to ru and back:  92%|█████████▏| 218/238 [45:12<04:14, 12.71s/it]
# Translating to ru and back:  92%|█████████▏| 219/238 [45:28<04:21, 13.77s/it]
# Translating to ru and back:  92%|█████████▏| 220/238 [45:38<03:45, 12.55s/it]
# Translating to ru and back:  93%|█████████▎| 221/238 [45:46<03:12, 11.33s/it]
# Translating to ru and back:  93%|█████████▎| 222/238 [46:00<03:10, 11.92s/it]
# Translating to ru and back:  94%|█████████▎| 223/238 [46:09<02:49, 11.32s/it]
# Translating to ru and back:  94%|█████████▍| 224/238 [46:24<02:50, 12.21s/it]
# Translating to ru and back:  95%|█████████▍| 225/238 [46:38<02:46, 12.77s/it]
# Translating to ru and back:  95%|█████████▍| 226/238 [46:50<02:32, 12.72s/it]
# Translating to ru and back:  95%|█████████▌| 227/238 [47:03<02:18, 12.57s/it]
# Translating to ru and back:  96%|█████████▌| 228/238 [47:10<01:51, 11.13s/it]
# Translating to ru and back:  96%|█████████▌| 229/238 [47:22<01:41, 11.32s/it]
# Translating to ru and back:  97%|█████████▋| 230/238 [47:31<01:24, 10.52s/it]
# Translating to ru and back:  97%|█████████▋| 231/238 [47:43<01:17, 11.00s/it]
# Translating to ru and back:  97%|█████████▋| 232/238 [47:53<01:04, 10.73s/it]
# Translating to ru and back:  98%|█████████▊| 233/238 [48:04<00:53, 10.64s/it]
# Translating to ru and back:  98%|█████████▊| 234/238 [48:14<00:42, 10.51s/it]
# Translating to ru and back:  99%|█████████▊| 235/238 [48:23<00:30, 10.14s/it]
# Translating to ru and back:  99%|█████████▉| 236/238 [48:37<00:22, 11.17s/it]
# Translating to ru and back: 100%|█████████▉| 237/238 [48:52<00:12, 12.39s/it]
# Translating to ru and back: 100%|██████████| 238/238 [49:10<00:00, 12.40s/it]
# Processing languages: 100%|██████████| 6/6 [4:45:26<00:00, 2854.44s/it]

# %%
ds=df.to_pandas()
ds = ds.drop(columns=["index"])
ds.reset_index(inplace=True)
if torch.cuda.is_available():
    torch.cuda.empty_cache()
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7614 entries, 0 to 7613
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   index                              7614 non-null   int64
#  1   class                              7614 non-null   object
#  2   comment_sentence                   7614 non-null   object
#  3   partition                          7614 non-null   int64
#  4   combo                              7614 non-null   object
#  5   labels                             7614 non-null   object
#  6   retranslated_text_english_from_de  7614 non-null   object
#  7   retranslated_text_english_from_fr  7614 non-null   object
#  8   retranslated_text_english_from_zh  7614 non-null   object
#  9   retranslated_text_english_from_hi  7614 non-null   object
#  10  retranslated_text_english_from_es  7614 non-null   object
#  11  retranslated_text_english_from_ru  7614 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 713.9+ KB

# %%
# Define the model and tokenizer for sentence encoding
model_name = "sentence-transformers/all-MiniLM-L6-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name).to("cuda" if torch.cuda.is_available() else "cpu")

# List of languages for retranslation analysis

languages = ["de", "fr", "zh", "hi", "es", "ru"]

# Function to encode sentences in batches for efficiency
def encode_sentences_in_batches(sentences, batch_size=32):
    """
    Encodes a list of sentences in batches using the pre-trained model.
    Args:
        sentences (list): List of sentences to encode.
        batch_size (int): Size of each batch for encoding.
    Returns:
        torch.Tensor: Tensor containing embeddings for all sentences.
    """
    embeddings = []
    for i in range(0, len(sentences), batch_size):
        batch = sentences[i:i+batch_size]
        # Tokenize and move inputs to the appropriate device (CPU/GPU)
        inputs = tokenizer(batch, padding=True, truncation=True, return_tensors="pt").to("cuda" if torch.cuda.is_available() else "cpu")
        with torch.no_grad():  # Disable gradient computation for inference
            model_output = model(**inputs)
        # Take the mean of the last hidden state to get sentence embeddings
        embeddings.append(model_output.last_hidden_state.mean(dim=1).cpu())
    return torch.cat(embeddings)

# Generate embeddings for original comments
comment_embeddings = encode_sentences_in_batches(ds['comment_sentence'].tolist())

# Set a cosine similarity threshold for filtering translations
threshold = 0.7

# Generate embeddings and filter translations for each language
language_columns = [f"retranslated_text_english_from_{lang}" for lang in languages]
for lang_col in language_columns:
    # Generate embeddings for the retranslated sentences
    retranslated_embeddings = encode_sentences_in_batches(ds[lang_col].fillna("").tolist())
    # Compute cosine similarity between original and retranslated embeddings
    cosine_similarities = torch.nn.functional.cosine_similarity(comment_embeddings, retranslated_embeddings).tolist()

    # Filter translations based on similarity threshold
    filtered_translation_col = f"filtered_{lang_col}"
    ds[filtered_translation_col] = [
        row[lang_col] if similarity > threshold else ""  # Keep translation if similarity exceeds threshold
        for (_, row), similarity in zip(ds.iterrows(), cosine_similarities)
    ]

# Prepare for concatenating original and filtered translations
main_columns = ['class', 'comment_sentence', 'labels']  # Main columns to retain in the final dataset
concat_columns = [f"filtered_{lang}" for lang in language_columns]  # Columns containing filtered translations

concat_types = ["de", "fr", "zh", "hi", "es", "ru"]

# Create a new DataFrame with original data
df_main = ds[main_columns].copy()
df_main['types'] = 'original'  # Add a column to indicate original comments

# Initialize a list to hold concatenated DataFrames
concat_data = [df_main]

# Add filtered translations to the concatenated DataFrame
for col, col_type in zip(concat_columns, concat_types):
    temp_df = df_main[main_columns].copy()  # Copy main structure
    temp_df['comment_sentence'] = ds[col]  # Replace 'comment_sentence' with filtered translations
    temp_df['types'] = col_type  # Label the type of translation
    concat_data.append(temp_df)  # Append to the list

# Concatenate all DataFrames into one
df_extended = pd.concat(concat_data, ignore_index=True)

# Remove rows with empty or null 'comment_sentence' values
df_extended = df_extended.dropna()  # Drop rows with null values
df_extended = df_extended[df_extended['comment_sentence'] != ""].reset_index(drop=True)  # Drop empty strings
# Display dataset information for debugging or confirmation
df_extended.info()
# Out:
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47169 entries, 0 to 47168
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   class             47169 non-null  object
#  1   comment_sentence  47169 non-null  object
#  2   labels            47169 non-null  object
#  3   types             47169 non-null  object
# dtypes: object(4)
# memory usage: 1.4+ MB

# %%
file_path = 'NLBSE_Dataset_Java.csv'

# Save the DataFrame to a CSV file
df_extended.to_csv(file_path, index=False)
print(f"DataFrame saved to {file_path}")
# Out:
# DataFrame saved to NLBSE_Dataset_Java.csv
