# %% [markdown]
# # Run in kaggle T4 * 2 gpu

# %%
# %pip install transformers
# %pip install datasets
# %pip install accelerate
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.46.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2024.6.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (3.1.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets) (3.15.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/conda/lib/python3.10/site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess<0.70.17 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.6.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.26.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->datasets) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.26.2)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /opt/conda/lib/python3.10/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.4.5)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (2.4.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (2024.6.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->accelerate) (3.1.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.6.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings("ignore")
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline, AutoModel
import torch
from datasets import load_dataset
import pandas as pd
from tqdm import tqdm
from accelerate import Accelerator

# %%
if torch.cuda.is_available():
    # Get the number of GPUs available
    num_gpus = torch.cuda.device_count()
    print(f"Number of GPUs available: {num_gpus}")
    
    # Print out the name of each GPU and memory details
    for i in range(num_gpus):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
        print(f"Total memory: {torch.cuda.get_device_properties(i).total_memory / 1e9} GB")
    
    # If multiple GPUs are available, use DataParallel for multi-GPU
    if num_gpus > 1:
        print("Using DataParallel for multi-GPU training.")
        # Example: Wrap your model with DataParallel
    else:
        print("Only one GPU available, using single GPU mode.")
else:
    print("No GPUs available, using CPU.")
    
def setup_translation_pipeline(source_lang, target_lang):
    """
    Set up a translation pipeline using a pretrained model from Helsinki-NLP, optimized for multi-GPU with Accelerate.

    Args:
        source_lang (str): The source language code (e.g., "en" for English).
        target_lang (str): The target language code (e.g., "fr" for French).

    Returns:
        transformers.Pipeline: A translation pipeline configured for the given language pair.
    """
    # Define the model name based on the source and target languages
    model_name = f"Helsinki-NLP/opus-mt-{source_lang}-{target_lang}"
    
    # Load the tokenizer for the specified model
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    
    # Load the translation model with memory optimization and half-precision support
    model = AutoModelForSeq2SeqLM.from_pretrained(
        model_name,
        return_dict=True,  # Use a dictionary for the model's output for easier access
        low_cpu_mem_usage=True,  # Optimize for low memory usage during model loading
        torch_dtype=torch.float16,  # Use half-precision for faster computation (requires supported GPU)
        trust_remote_code=True,  # Trust the model's remote configuration if specified
    )
    
    # Use the Accelerate library for better multi-GPU support
    accelerator = Accelerator()

    # Move the model to the appropriate device using Accelerator (handles multi-GPU)
    model = accelerator.prepare(model)

    # Set up and return the translation pipeline
    translation_pipeline = pipeline(
        "translation",  # Specify the task as translation
        model=model,  # Provide the loaded model
        tokenizer=tokenizer,  # Provide the loaded tokenizer
        torch_dtype=torch.float16,  # Use half-precision for the pipeline
        max_length=512,
        truncation=True,
        device=accelerator.device  # Use the device from Accelerator (handles multi-GPU)
    )

    return translation_pipeline
# Out:
# Number of GPUs available: 2
# GPU 0: Tesla T4
# Total memory: 15.828320256 GB
# GPU 1: Tesla T4
# Total memory: 15.828320256 GB
# Using DataParallel for multi-GPU training.

# %%
# Function to translate and retranslate for a given target language
def translate_retranslate(ds, source_lang, target_lang, batch_size=32):
    """
    Translate the dataset's 'comment_sentence' column to a target language and back to the source language.
    
    Args:
        ds (Dataset): Hugging Face dataset containing a 'comment_sentence' column.
        source_lang (str): Source language code (e.g., "en" for English).
        target_lang (str): Target language code to translate to and back.
        batch_size (int): Number of rows to process in a single batch.

    Returns:
        Dataset: Hugging Face dataset with a new column for retranslated texts.
    """
    # Set up translation pipelines
    pipe_to_target = setup_translation_pipeline(source_lang, target_lang)  # English to target language
    pipe_to_source = setup_translation_pipeline(target_lang, source_lang)  # Target language back to English

    retranslated_texts = []

    # Process the dataset in batches to optimize memory usage and speed
    for i in tqdm(range(0, len(ds), batch_size), desc=f"Translating to {target_lang} and back"):
        # Extract a batch of 'comment_sentence' without converting to pandas
        batch = ds[i: i + batch_size]["comment_sentence"]

        # Step 1: Translate from source language to target language
        target_translations = pipe_to_target(batch, max_length=512, do_sample=False)
        target_texts = [result["translation_text"] for result in target_translations]

        # Step 2: Translate back to the source language (English)
        english_translations = pipe_to_source(target_texts, max_length=512, do_sample=False)
        retranslated_batch = [result["translation_text"].strip() for result in english_translations]

        # Append the retranslated texts to the result list
        retranslated_texts.extend(retranslated_batch)
                # Clear CUDA cache to prevent memory overload
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    # Add the retranslated texts as a new column in the dataset
    ds = ds.add_column(f"retranslated_text_english_from_{target_lang}", retranslated_texts)
    return ds

# Load the dataset (e.g., the first 10 rows from the Python training split)
df = load_dataset("NLBSE/nlbse25-code-comment-classification", split="java_train")

# List of target languages to process for retranslation
languages = ["de", "fr", "zh", "hi", "es", "ru","ar","nl","it","ca"]
# Out:
# README.md:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# java_train-00000-of-00001.parquet:   0%|          | 0.00/680k [00:00<?, ?B/s]
# java_test-00000-of-00001.parquet:   0%|          | 0.00/174k [00:00<?, ?B/s]
# python_train-00000-of-00001.parquet:   0%|          | 0.00/126k [00:00<?, ?B/s]
# python_test-00000-of-00001.parquet:   0%|          | 0.00/35.7k [00:00<?, ?B/s]
# pharo_train-00000-of-00001.parquet:   0%|          | 0.00/113k [00:00<?, ?B/s]
# pharo_test-00000-of-00001.parquet:   0%|          | 0.00/30.6k [00:00<?, ?B/s]
# Generating java_train split:   0%|          | 0/7614 [00:00<?, ? examples/s]
# Generating java_test split:   0%|          | 0/1725 [00:00<?, ? examples/s]
# Generating python_train split:   0%|          | 0/1884 [00:00<?, ? examples/s]
# Generating python_test split:   0%|          | 0/406 [00:00<?, ? examples/s]
# Generating pharo_train split:   0%|          | 0/1298 [00:00<?, ? examples/s]
# Generating pharo_test split:   0%|          | 0/289 [00:00<?, ? examples/s]

# %%
ds=df.to_pandas()
from datasets import Dataset
filter_ds = ds[~ds['labels'].apply(lambda x: str(x).startswith("[1 0 0 0 0 0 0]"))]
unfilter_ds =  ds[ds['labels'].apply(lambda x: str(x).startswith("[1 0 0 0 0 0 0]"))]
filter_df = Dataset.from_pandas(filter_ds)
filter_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4064 entries, 1 to 7605
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             4064 non-null   int64
#  1   class             4064 non-null   object
#  2   comment_sentence  4064 non-null   object
#  3   partition         4064 non-null   int64
#  4   combo             4064 non-null   object
#  5   labels            4064 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 222.2+ KB

# %%
for lang in tqdm(languages, desc="Processing languages"):
    filter_df = translate_retranslate(filter_df, "en", lang)
# Out:
# Processing languages:   0%|          | 0/10 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/768k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/797k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/298M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/797k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/768k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/298M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to de and back:   0%|          | 0/127 [00:00<?, ?it/s]
# Translating to de and back:   1%|          | 1/127 [00:10<23:01, 10.96s/it]
# Translating to de and back:   2%|▏         | 2/127 [00:19<20:12,  9.70s/it]
# Translating to de and back:   2%|▏         | 3/127 [00:28<18:52,  9.13s/it]
# Translating to de and back:   3%|▎         | 4/127 [00:37<18:58,  9.25s/it]Your input_length: 510 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 510 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 510 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:   4%|▍         | 5/127 [01:09<35:43, 17.57s/it]
# Translating to de and back:   5%|▍         | 6/127 [01:17<28:26, 14.10s/it]
# Translating to de and back:   6%|▌         | 7/127 [01:34<30:09, 15.08s/it]
# Translating to de and back:   6%|▋         | 8/127 [01:41<24:49, 12.52s/it]
# Translating to de and back:   7%|▋         | 9/127 [01:50<22:21, 11.37s/it]
# Translating to de and back:   8%|▊         | 10/127 [02:01<21:52, 11.22s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#
# Translating to de and back:   9%|▊         | 11/127 [02:09<19:51, 10.27s/it]
# Translating to de and back:   9%|▉         | 12/127 [02:17<18:17,  9.55s/it]
# Translating to de and back:  10%|█         | 13/127 [02:24<16:41,  8.79s/it]
# Translating to de and back:  11%|█         | 14/127 [02:33<16:48,  8.92s/it]
# Translating to de and back:  12%|█▏        | 15/127 [03:11<33:00, 17.68s/it]
# Translating to de and back:  13%|█▎        | 16/127 [03:20<27:58, 15.12s/it]
# Translating to de and back:  13%|█▎        | 17/127 [03:30<24:52, 13.57s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  14%|█▍        | 18/127 [03:46<25:42, 14.15s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  15%|█▍        | 19/127 [04:10<31:06, 17.28s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  16%|█▌        | 20/127 [04:24<29:09, 16.35s/it]
# Translating to de and back:  17%|█▋        | 21/127 [04:33<24:47, 14.03s/it]
# Translating to de and back:  17%|█▋        | 22/127 [04:43<22:18, 12.75s/it]
# Translating to de and back:  18%|█▊        | 23/127 [04:52<20:23, 11.77s/it]
# Translating to de and back:  19%|█▉        | 24/127 [05:00<18:00, 10.49s/it]
# Translating to de and back:  20%|█▉        | 25/127 [05:08<16:36,  9.77s/it]
# Translating to de and back:  20%|██        | 26/127 [05:24<19:53, 11.82s/it]
# Translating to de and back:  21%|██▏       | 27/127 [05:34<18:26, 11.06s/it]
# Translating to de and back:  22%|██▏       | 28/127 [05:41<16:28,  9.99s/it]
# Translating to de and back:  23%|██▎       | 29/127 [05:50<15:39,  9.58s/it]
# Translating to de and back:  24%|██▎       | 30/127 [06:04<17:55, 11.09s/it]
# Translating to de and back:  24%|██▍       | 31/127 [06:13<16:41, 10.43s/it]
# Translating to de and back:  25%|██▌       | 32/127 [06:23<16:09, 10.20s/it]
# Translating to de and back:  26%|██▌       | 33/127 [06:32<15:28,  9.88s/it]
# Translating to de and back:  27%|██▋       | 34/127 [06:39<14:00,  9.04s/it]
# Translating to de and back:  28%|██▊       | 35/127 [06:47<13:22,  8.72s/it]
# Translating to de and back:  28%|██▊       | 36/127 [06:55<12:48,  8.44s/it]
# Translating to de and back:  29%|██▉       | 37/127 [07:17<18:40, 12.45s/it]Your input_length: 510 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 510 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  30%|██▉       | 38/127 [07:45<25:35, 17.25s/it]
# Translating to de and back:  31%|███       | 39/127 [07:53<21:15, 14.50s/it]
# Translating to de and back:  31%|███▏      | 40/127 [08:08<20:57, 14.45s/it]
# Translating to de and back:  32%|███▏      | 41/127 [08:17<18:32, 12.93s/it]Your input_length: 510 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  33%|███▎      | 42/127 [09:05<33:07, 23.38s/it]
# Translating to de and back:  34%|███▍      | 43/127 [09:22<30:18, 21.65s/it]
# Translating to de and back:  35%|███▍      | 44/127 [09:34<25:46, 18.64s/it]
# Translating to de and back:  35%|███▌      | 45/127 [09:45<22:23, 16.39s/it]
# Translating to de and back:  36%|███▌      | 46/127 [09:52<18:13, 13.50s/it]
# Translating to de and back:  37%|███▋      | 47/127 [10:03<16:57, 12.72s/it]
# Translating to de and back:  38%|███▊      | 48/127 [10:13<15:44, 11.95s/it]
/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  66%|██████▌   | 84/127 [19:12<29:05, 40.60s/it]
# Translating to de and back:  67%|██████▋   | 85/127 [19:31<23:42, 33.88s/it]
# Translating to de and back:  68%|██████▊   | 86/127 [19:39<17:58, 26.29s/it]
# Translating to de and back:  69%|██████▊   | 87/127 [19:50<14:28, 21.72s/it]
# Translating to de and back:  69%|██████▉   | 88/127 [20:04<12:28, 19.20s/it]
# Translating to de and back:  70%|███████   | 89/127 [20:14<10:25, 16.46s/it]
# Translating to de and back:  71%|███████   | 90/127 [20:30<10:06, 16.39s/it]
# Translating to de and back:  72%|███████▏  | 91/127 [20:38<08:22, 13.95s/it]
# Translating to de and back:  72%|███████▏  | 92/127 [20:47<07:11, 12.33s/it]
# Translating to de and back:  73%|███████▎  | 93/127 [20:56<06:24, 11.30s/it]
# Translating to de and back:  74%|███████▍  | 94/127 [21:10<06:47, 12.36s/it]
# Translating to de and back:  75%|███████▍  | 95/127 [21:27<07:19, 13.73s/it]
# Translating to de and back:  76%|███████▌  | 96/127 [21:37<06:30, 12.58s/it]
# Translating to de and back:  76%|███████▋  | 97/127 [21:47<05:53, 11.79s/it]
# Translating to de and back:  77%|███████▋  | 98/127 [22:00<05:47, 11.98s/it]
# Translating to de and back:  78%|███████▊  | 99/127 [22:14<05:57, 12.76s/it]
# Translating to de and back:  79%|███████▊  | 100/127 [22:32<06:22, 14.15s/it]
# Translating to de and back:  80%|███████▉  | 101/127 [22:43<05:47, 13.38s/it]
# Translating to de and back:  80%|████████  | 102/127 [22:57<05:36, 13.47s/it]
# Translating to de and back:  81%|████████  | 103/127 [23:08<05:09, 12.90s/it]
# Translating to de and back:  82%|████████▏ | 104/127 [23:26<05:31, 14.42s/it]
# Translating to de and back:  83%|████████▎ | 105/127 [23:42<05:28, 14.91s/it]
# Translating to de and back:  83%|████████▎ | 106/127 [23:52<04:40, 13.35s/it]
# Translating to de and back:  84%|████████▍ | 107/127 [24:01<04:00, 12.01s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  85%|████████▌ | 108/127 [24:39<06:16, 19.82s/it]
# Translating to de and back:  86%|████████▌ | 109/127 [24:52<05:16, 17.59s/it]
# Translating to de and back:  87%|████████▋ | 110/127 [25:01<04:15, 15.03s/it]
# Translating to de and back:  87%|████████▋ | 111/127 [25:09<03:31, 13.20s/it]
# Translating to de and back:  88%|████████▊ | 112/127 [25:26<03:35, 14.33s/it]
# Translating to de and back:  89%|████████▉ | 113/127 [25:35<02:57, 12.68s/it]
# Translating to de and back:  90%|████████▉ | 114/127 [25:46<02:37, 12.09s/it]
# Translating to de and back:  91%|█████████ | 115/127 [26:00<02:31, 12.62s/it]
# Translating to de and back:  91%|█████████▏| 116/127 [26:18<02:36, 14.20s/it]
# Translating to de and back:  92%|█████████▏| 117/127 [26:28<02:10, 13.01s/it]
# Translating to de and back:  93%|█████████▎| 118/127 [26:38<01:48, 12.05s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to de and back:  94%|█████████▎| 119/127 [28:02<04:29, 33.68s/it]
# Translating to de and back:  94%|█████████▍| 120/127 [28:16<03:14, 27.76s/it]
# Translating to de and back:  95%|█████████▌| 121/127 [28:29<02:20, 23.44s/it]
# Translating to de and back:  96%|█████████▌| 122/127 [28:39<01:36, 19.26s/it]
# Translating to de and back:  97%|█████████▋| 123/127 [28:50<01:07, 16.96s/it]
# Translating to de and back:  98%|█████████▊| 124/127 [29:03<00:47, 15.71s/it]
# Translating to de and back:  98%|█████████▊| 125/127 [29:13<00:27, 13.90s/it]
# Translating to de and back:  99%|█████████▉| 126/127 [29:26<00:13, 13.56s/it]
# Translating to de and back: 100%|██████████| 127/127 [29:51<00:00, 14.11s/it]
# Processing languages:  10%|█         | 1/10 [30:03<4:30:28, 1803.21s/it]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to fr and back:   0%|          | 0/127 [00:00<?, ?it/s]
# Translating to fr and back:   1%|          | 1/127 [00:09<20:52,  9.94s/it]
# Translating to fr and back:   2%|▏         | 2/127 [00:18<19:06,  9.17s/it]
# Translating to fr and back:   2%|▏         | 3/127 [00:26<18:11,  8.80s/it]
# Translating to fr and back:   3%|▎         | 4/127 [00:35<18:03,  8.81s/it]
# Translating to fr and back:   4%|▍         | 5/127 [00:43<16:58,  8.35s/it]
# Translating to fr and back:   5%|▍         | 6/127 [00:50<16:02,  7.96s/it]
# Translating to fr and back:   6%|▌         | 7/127 [00:59<16:52,  8.44s/it]
# Translating to fr and back:   6%|▋         | 8/127 [01:06<15:48,  7.97s/it]
# Translating to fr and back:   7%|▋         | 9/127 [01:15<16:14,  8.26s/it]
# Translating to fr and back:   8%|▊         | 10/127 [01:25<16:59,  8.71s/it]
# Translating to fr and back:   9%|▊         | 11/127 [01:33<16:20,  8.45s/it]
# Translating to fr and back:   9%|▉         | 12/127 [01:41<16:15,  8.48s/it]
# Translating to fr and back:  10%|█         | 13/127 [01:48<15:17,  8.05s/it]
# Translating to fr and back:  11%|█         | 14/127 [01:58<15:48,  8.39s/it]
# Translating to fr and back:  12%|█▏        | 15/127 [02:05<15:10,  8.13s/it]
# Translating to fr and back:  13%|█▎        | 16/127 [02:14<15:41,  8.49s/it]
# Translating to fr and back:  13%|█▎        | 17/127 [02:24<16:12,  8.84s/it]
# Translating to fr and back:  14%|█▍        | 18/127 [02:32<15:16,  8.40s/it]
# Translating to fr and back:  15%|█▍        | 19/127 [02:42<16:19,  9.07s/it]
# Translating to fr and back:  16%|█▌        | 20/127 [02:50<15:40,  8.79s/it]
# Translating to fr and back:  17%|█▋        | 21/127 [02:59<15:16,  8.64s/it]
# Translating to fr and back:  17%|█▋        | 22/127 [03:08<15:32,  8.88s/it]
# Translating to fr and back:  18%|█▊        | 23/127 [03:18<15:42,  9.07s/it]
# Translating to fr and back:  19%|█▉        | 24/127 [03:28<16:02,  9.34s/it]
# Translating to fr and back:  20%|█▉        | 25/127 [03:36<15:14,  8.97s/it]
# Translating to fr and back:  20%|██        | 26/127 [03:46<15:55,  9.46s/it]
# Translating to fr and back:  21%|██▏       | 27/127 [03:55<15:37,  9.38s/it]
# Translating to fr and back:  22%|██▏       | 28/127 [04:05<15:34,  9.44s/it]
# Translating to fr and back:  23%|██▎       | 29/127 [04:14<15:07,  9.26s/it]
# Translating to fr and back:  24%|██▎       | 30/127 [04:23<14:42,  9.09s/it]
# Translating to fr and back:  24%|██▍       | 31/127 [04:31<14:24,  9.00s/it]
# Translating to fr and back:  25%|██▌       | 32/127 [04:41<14:27,  9.13s/it]
# Translating to fr and back:  84%|████████▍ | 107/127 [19:44<04:00, 12.01s/it]
# Translating to fr and back:  85%|████████▌ | 108/127 [20:00<04:13, 13.36s/it]
# Translating to fr and back:  86%|████████▌ | 109/127 [20:12<03:53, 12.98s/it]
# Translating to fr and back:  87%|████████▋ | 110/127 [20:21<03:20, 11.80s/it]
# Translating to fr and back:  87%|████████▋ | 111/127 [20:30<02:54, 10.88s/it]
# Translating to fr and back:  88%|████████▊ | 112/127 [20:47<03:11, 12.78s/it]
# Translating to fr and back:  89%|████████▉ | 113/127 [20:56<02:40, 11.49s/it]
# Translating to fr and back:  90%|████████▉ | 114/127 [21:06<02:23, 11.02s/it]
# Translating to fr and back:  91%|█████████ | 115/127 [21:19<02:21, 11.78s/it]
# Translating to fr and back:  91%|█████████▏| 116/127 [21:37<02:30, 13.66s/it]
# Translating to fr and back:  92%|█████████▏| 117/127 [21:47<02:05, 12.57s/it]
# Translating to fr and back:  93%|█████████▎| 118/127 [21:57<01:45, 11.75s/it]
# Translating to fr and back:  94%|█████████▎| 119/127 [22:10<01:35, 11.94s/it]
# Translating to fr and back:  94%|█████████▍| 120/127 [22:24<01:28, 12.71s/it]
# Translating to fr and back:  95%|█████████▌| 121/127 [22:38<01:17, 12.93s/it]
# Translating to fr and back:  96%|█████████▌| 122/127 [22:47<00:59, 11.83s/it]
# Translating to fr and back:  97%|█████████▋| 123/127 [22:58<00:47, 11.76s/it]
# Translating to fr and back:  98%|█████████▊| 124/127 [23:11<00:36, 12.02s/it]
# Translating to fr and back:  98%|█████████▊| 125/127 [23:21<00:22, 11.30s/it]
# Translating to fr and back:  99%|█████████▉| 126/127 [23:33<00:11, 11.59s/it]
# Translating to fr and back: 100%|██████████| 127/127 [23:59<00:00, 11.33s/it]
# Processing languages:  20%|██        | 2/10 [54:11<3:32:37, 1594.69s/it]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/806k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/805k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.62M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/805k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/807k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.62M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to zh and back:   0%|          | 0/127 [00:00<?, ?it/s]
# Translating to zh and back:   1%|          | 1/127 [00:18<38:26, 18.31s/it]
# Translating to zh and back:   2%|▏         | 2/127 [00:28<27:55, 13.40s/it]
# Translating to zh and back:   2%|▏         | 3/127 [00:36<22:51, 11.06s/it]
# Translating to zh and back:   3%|▎         | 4/127 [00:47<22:36, 11.03s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to zh and back:   4%|▍         | 5/127 [01:03<25:59, 12.79s/it]
# Translating to zh and back:   5%|▍         | 6/127 [01:11<22:25, 11.12s/it]
# Translating to zh and back:   6%|▌         | 7/127 [01:21<21:30, 10.75s/it]
# Translating to zh and back:   6%|▋         | 8/127 [01:30<20:34, 10.38s/it]
# Translating to zh and back:   7%|▋         | 9/127 [01:40<19:45, 10.05s/it]
# Translating to zh and back:   8%|▊         | 10/127 [01:52<21:06, 10.83s/it]
# Translating to zh and back:   9%|▊         | 11/127 [02:01<19:40, 10.17s/it]
# Translating to zh and back:   9%|▉         | 12/127 [02:20<24:28, 12.77s/it]
# Translating to zh and back:  10%|█         | 13/127 [02:27<21:03, 11.09s/it]
# Translating to zh and back:  11%|█         | 14/127 [02:37<20:13, 10.74s/it]
# Translating to zh and back:  72%|███████▏  | 91/127 [21:45<08:51, 14.76s/it]
# Translating to zh and back:  72%|███████▏  | 92/127 [21:56<07:56, 13.61s/it]
# Translating to zh and back:  73%|███████▎  | 93/127 [22:07<07:20, 12.95s/it]
# Translating to zh and back:  74%|███████▍  | 94/127 [22:24<07:39, 13.91s/it]Your input_length: 508 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to zh and back:  75%|███████▍  | 95/127 [22:52<09:46, 18.32s/it]
# Translating to zh and back:  76%|███████▌  | 96/127 [23:04<08:28, 16.42s/it]
# Translating to zh and back:  76%|███████▋  | 97/127 [23:16<07:30, 15.02s/it]
# Translating to zh and back:  77%|███████▋  | 98/127 [23:31<07:14, 14.99s/it]
# Translating to zh and back:  78%|███████▊  | 99/127 [23:51<07:40, 16.46s/it]
# Translating to zh and back:  79%|███████▊  | 100/127 [24:11<07:57, 17.67s/it]
# Translating to zh and back:  80%|███████▉  | 101/127 [24:26<07:16, 16.80s/it]
# Translating to zh and back:  80%|████████  | 102/127 [24:48<07:39, 18.39s/it]
# Translating to zh and back:  81%|████████  | 103/127 [25:01<06:41, 16.74s/it]
# Translating to zh and back:  82%|████████▏ | 104/127 [25:23<07:02, 18.35s/it]Your input_length: 502 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to zh and back:  83%|████████▎ | 105/127 [25:46<07:11, 19.61s/it]
# Translating to zh and back:  83%|████████▎ | 106/127 [26:01<06:25, 18.35s/it]
# Translating to zh and back:  84%|████████▍ | 107/127 [26:12<05:22, 16.12s/it]
# Translating to zh and back:  85%|████████▌ | 108/127 [26:30<05:16, 16.67s/it]
# Translating to zh and back:  86%|████████▌ | 109/127 [26:44<04:44, 15.79s/it]
# Translating to zh and back:  87%|████████▋ | 110/127 [26:54<03:58, 14.01s/it]
# Translating to zh and back:  87%|████████▋ | 111/127 [27:05<03:32, 13.28s/it]
# Translating to zh and back:  88%|████████▊ | 112/127 [27:25<03:48, 15.26s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to zh and back:  89%|████████▉ | 113/127 [27:47<04:03, 17.38s/it]
# Translating to zh and back:  90%|████████▉ | 114/127 [28:18<04:38, 21.45s/it]
# Translating to zh and back:  91%|█████████ | 115/127 [28:34<03:55, 19.60s/it]
# Translating to zh and back:  91%|█████████▏| 116/127 [28:53<03:35, 19.56s/it]
# Translating to zh and back:  92%|█████████▏| 117/127 [29:04<02:49, 16.96s/it]
# Translating to zh and back:  93%|█████████▎| 118/127 [29:19<02:27, 16.43s/it]
# Translating to zh and back:  94%|█████████▎| 119/127 [29:33<02:06, 15.78s/it]
# Translating to zh and back:  94%|█████████▍| 120/127 [29:50<01:52, 16.10s/it]
# Translating to zh and back:  95%|█████████▌| 121/127 [30:05<01:33, 15.64s/it]
# Translating to zh and back:  96%|█████████▌| 122/127 [30:16<01:11, 14.23s/it]
# Translating to zh and back:  97%|█████████▋| 123/127 [30:30<00:56, 14.17s/it]
# Translating to zh and back:  98%|█████████▊| 124/127 [30:45<00:43, 14.53s/it]
# Translating to zh and back:  98%|█████████▊| 125/127 [30:58<00:27, 13.89s/it]Your input_length: 511 is bigger than 0.9 * max_length: 512. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
#
# Translating to zh and back:  99%|█████████▉| 126/127 [31:23<00:17, 17.36s/it]
# Translating to zh and back: 100%|██████████| 127/127 [31:50<00:00, 15.04s/it]
# Processing languages:  30%|███       | 3/10 [1:26:11<3:23:20, 1742.98s/it]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/812k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/306M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/813k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.06M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/304M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to hi and back:   0%|          | 0/127 [00:00<?, ?it/s]
# Translating to hi and back:   1%|          | 1/127 [00:08<18:33,  8.83s/it]
# Translating to hi and back:   2%|▏         | 2/127 [00:16<17:30,  8.40s/it]
# Translating to hi and back:   2%|▏         | 3/127 [00:24<16:43,  8.09s/it]
# Translating to hi and back:   3%|▎         | 4/127 [00:33<16:53,  8.24s/it]
# Translating to hi and back:   4%|▍         | 5/127 [00:39<15:27,  7.60s/it]
# Translating to hi and back:   5%|▍         | 6/127 [00:46<14:42,  7.29s/it]
# Translating to hi and back:   6%|▌         | 7/127 [00:55<15:36,  7.80s/it]
# Translating to hi and back:   6%|▋         | 8/127 [01:01<14:50,  7.48s/it]
# Translating to hi and back:   7%|▋         | 9/127 [01:10<15:32,  7.91s/it]
# Translating to hi and back:   8%|▊         | 10/127 [01:20<16:13,  8.32s/it]
# Translating to hi and back:   9%|▊         | 11/127 [01:28<16:03,  8.30s/it]
# Translating to hi and back:   9%|▉         | 12/127 [01:39<17:46,  9.27s/it]
# Translating to hi and back:  10%|█         | 13/127 [01:47<16:37,  8.75s/it]
# Translating to hi and back:  11%|█         | 14/127 [01:57<17:02,  9.05s/it]
# Translating to hi and back:  12%|█▏        | 15/127 [02:05<16:27,  8.82s/it]
# Translating to hi and back:  13%|█▎        | 16/127 [02:17<18:09,  9.81s/it]
# Translating to hi and back:  13%|█▎        | 17/127 [02:26<17:25,  9.51s/it]
# Translating to hi and back:  14%|█▍        | 18/127 [02:33<16:06,  8.87s/it]
# Translating to hi and back:  15%|█▍        | 19/127 [02:43<16:28,  9.16s/it]
# Translating to hi and back:  16%|█▌        | 20/127 [02:54<17:30,  9.81s/it]
# Translating to hi and back:  17%|█▋        | 21/127 [03:10<20:27, 11.58s/it]
# Translating to hi and back:  17%|█▋        | 22/127 [03:23<21:13, 12.13s/it]
# Translating to hi and back:  18%|█▊        | 23/127 [03:32<19:12, 11.08s/it]
# Translating to hi and back:  19%|█▉        | 24/127 [03:40<17:15, 10.05s/it]
# Translating to hi and back:  20%|█▉        | 25/127 [03:48<16:11,  9.52s/it]
# Translating to hi and back:  20%|██        | 26/127 [03:56<15:20,  9.11s/it]
# Translating to hi and back:  21%|██▏       | 27/127 [04:05<15:04,  9.05s/it]
# Translating to hi and back:  22%|██▏       | 28/127 [04:12<14:05,  8.54s/it]
# Translating to hi and back:  23%|██▎       | 29/127 [04:25<16:04,  9.84s/it]
# Translating to hi and back:  24%|██▎       | 30/127 [04:32<14:37,  9.05s/it]
# Translating to hi and back:  24%|██▍       | 31/127 [04:40<13:55,  8.70s/it]
# Translating to hi and back:  25%|██▌       | 32/127 [04:53<15:49,  9.99s/it]
# Translating to hi and back:  26%|██▌       | 33/127 [05:01<14:30,  9.26s/it]
# Translating to hi and back:  27%|██▋       | 34/127 [05:08<13:22,  8.63s/it]
# Translating to hi and back:  28%|██▊       | 35/127 [05:17<13:15,  8.65s/it]
# Translating to hi and back:  57%|█████▋    | 72/127 [12:07<10:16, 11.20s/it]
# Translating to hi and back:  57%|█████▋    | 73/127 [12:17<09:37, 10.70s/it]
# Translating to hi and back:  58%|█████▊    | 74/127 [12:30<10:09, 11.49s/it]
# Translating to hi and back:  59%|█████▉    | 75/127 [12:39<09:13, 10.65s/it]
# Translating to hi and back:  60%|█████▉    | 76/127 [12:45<07:58,  9.38s/it]
# Translating to hi and back:  61%|██████    | 77/127 [12:51<06:52,  8.25s/it]
# ...
# Translating to it and back:  52%|█████▏    | 66/127 [13:34<15:21, 15.10s/it]
# Translating to it and back:  53%|█████▎    | 67/127 [13:46<14:09, 14.16s/it]
# Translating to it and back:  54%|█████▎    | 68/127 [14:06<15:38, 15.91s/it]
# Translating to it and back:  54%|█████▍    | 69/127 [14:20<14:54, 15.42s/it]
# Translating to it and back:  55%|█████▌    | 70/127 [14:33<13:52, 14.61s/it]
# Translating to it and back:  56%|█████▌    | 71/127 [14:47<13:30, 14.47s/it]
# Translating to it and back:  57%|█████▋    | 72/127 [15:03<13:44, 15.00s/it]
# Translating to it and back:  57%|█████▋    | 73/127 [15:17<13:03, 14.50s/it]
# Translating to it and back:  58%|█████▊    | 74/127 [15:33<13:24, 15.17s/it]
# Translating to it and back:  59%|█████▉    | 75/127 [15:44<12:05, 13.96s/it]
# Translating to it and back:  60%|█████▉    | 76/127 [15:54<10:43, 12.63s/it]
# Translating to it and back:  61%|██████    | 77/127 [16:05<10:04, 12.08s/it]
# Translating to it and back:  61%|██████▏   | 78/127 [16:18<10:06, 12.39s/it]
# Translating to it and back:  62%|██████▏   | 79/127 [16:42<12:50, 16.06s/it]
# Translating to it and back:  63%|██████▎   | 80/127 [16:55<11:39, 14.89s/it]
# Translating to it and back:  64%|██████▍   | 81/127 [17:07<10:56, 14.27s/it]
# Translating to it and back:  65%|██████▍   | 82/127 [17:20<10:21, 13.80s/it]
# Translating to it and back:  65%|██████▌   | 83/127 [17:36<10:34, 14.43s/it]
# Translating to it and back:  66%|██████▌   | 84/127 [17:48<09:52, 13.78s/it]
# Translating to it and back:  67%|██████▋   | 85/127 [18:09<11:05, 15.84s/it]
# Translating to it and back:  68%|██████▊   | 86/127 [18:20<09:45, 14.28s/it]
# Translating to it and back:  69%|██████▊   | 87/127 [18:33<09:18, 13.96s/it]
# Translating to it and back:  69%|██████▉   | 88/127 [18:48<09:16, 14.26s/it]
# Translating to it and back:  70%|███████   | 89/127 [19:01<08:46, 13.86s/it]
# Translating to it and back:  71%|███████   | 90/127 [19:19<09:26, 15.30s/it]
# Translating to it and back:  72%|███████▏  | 91/127 [19:30<08:19, 13.87s/it]
# Translating to it and back:  72%|███████▏  | 92/127 [19:39<07:15, 12.45s/it]
# Translating to it and back:  73%|███████▎  | 93/127 [19:57<07:56, 14.01s/it]
# Translating to it and back:  74%|███████▍  | 94/127 [20:16<08:32, 15.52s/it]
# Translating to it and back:  75%|███████▍  | 95/127 [20:35<08:56, 16.77s/it]
# Translating to it and back:  76%|███████▌  | 96/127 [20:47<07:50, 15.19s/it]
# Translating to it and back:  76%|███████▋  | 97/127 [21:02<07:35, 15.17s/it]
# Translating to it and back:  77%|███████▋  | 98/127 [21:17<07:17, 15.09s/it]
# Translating to it and back:  78%|███████▊  | 99/127 [21:34<07:19, 15.68s/it]
# Translating to it and back:  79%|███████▊  | 100/127 [21:55<07:44, 17.19s/it]
# Translating to it and back:  80%|███████▉  | 101/127 [22:09<07:04, 16.31s/it]
# Translating to it and back:  80%|████████  | 102/127 [22:25<06:47, 16.32s/it]
# Translating to it and back:  81%|████████  | 103/127 [22:39<06:12, 15.53s/it]
# Translating to it and back:  82%|████████▏ | 104/127 [23:00<06:31, 17.04s/it]
# Translating to it and back:  83%|████████▎ | 105/127 [23:18<06:20, 17.30s/it]
# Translating to it and back:  83%|████████▎ | 106/127 [23:29<05:27, 15.61s/it]
# Translating to it and back:  84%|████████▍ | 107/127 [23:40<04:45, 14.28s/it]
# Translating to it and back:  85%|████████▌ | 108/127 [23:58<04:52, 15.39s/it]
# Translating to it and back:  86%|████████▌ | 109/127 [24:13<04:31, 15.09s/it]
# Translating to it and back:  87%|████████▋ | 110/127 [24:24<03:54, 13.80s/it]
# Translating to it and back:  87%|████████▋ | 111/127 [24:34<03:26, 12.88s/it]
# Translating to it and back:  88%|████████▊ | 112/127 [24:55<03:46, 15.12s/it]
# Translating to it and back:  89%|████████▉ | 113/127 [25:09<03:26, 14.77s/it]
# Translating to it and back:  90%|████████▉ | 114/127 [25:22<03:06, 14.31s/it]
# Translating to it and back:  91%|█████████ | 115/127 [25:38<02:57, 14.79s/it]
# Translating to it and back:  91%|█████████▏| 116/127 [25:58<03:00, 16.41s/it]
# Translating to it and back:  92%|█████████▏| 117/127 [26:10<02:29, 14.99s/it]
# Translating to it and back:  93%|█████████▎| 118/127 [26:21<02:06, 14.07s/it]
# Translating to it and back:  94%|█████████▎| 119/127 [26:35<01:51, 13.97s/it]
# Translating to it and back:  94%|█████████▍| 120/127 [26:52<01:44, 14.86s/it]
# Translating to it and back:  95%|█████████▌| 121/127 [27:07<01:29, 14.91s/it]
# Translating to it and back:  96%|█████████▌| 122/127 [27:19<01:09, 13.89s/it]
# Translating to it and back:  97%|█████████▋| 123/127 [27:33<00:55, 13.86s/it]
# Translating to it and back:  98%|█████████▊| 124/127 [27:47<00:42, 14.13s/it]
# Translating to it and back:  98%|█████████▊| 125/127 [27:59<00:26, 13.47s/it]
# Translating to it and back:  99%|█████████▉| 126/127 [28:14<00:13, 13.95s/it]
# Translating to it and back: 100%|██████████| 127/127 [28:43<00:00, 13.57s/it]
# Processing languages:  90%|█████████ | 9/10 [4:21:18<30:00, 1800.88s/it]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/803k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/815k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.26M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/292M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/815k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/803k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.26M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/292M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Translating to ca and back:   0%|          | 0/127 [00:00<?, ?it/s]
# Translating to ca and back:   1%|          | 1/127 [00:08<17:29,  8.33s/it]
# Translating to ca and back:   2%|▏         | 2/127 [00:16<17:30,  8.40s/it]
# Translating to ca and back:   2%|▏         | 3/127 [00:24<17:04,  8.26s/it]
# Translating to ca and back:   3%|▎         | 4/127 [00:34<17:42,  8.64s/it]
# Translating to ca and back:   4%|▍         | 5/127 [00:41<16:27,  8.10s/it]
# Translating to ca and back:  91%|█████████▏| 116/127 [21:19<02:41, 14.66s/it]
# Translating to ca and back:  92%|█████████▏| 117/127 [21:29<02:13, 13.31s/it]
# Translating to ca and back:  93%|█████████▎| 118/127 [21:38<01:48, 12.10s/it]
# Translating to ca and back:  94%|█████████▎| 119/127 [21:50<01:36, 12.03s/it]
# Translating to ca and back:  94%|█████████▍| 120/127 [22:04<01:28, 12.61s/it]
# Translating to ca and back:  95%|█████████▌| 121/127 [22:17<01:15, 12.60s/it]
# Translating to ca and back:  96%|█████████▌| 122/127 [22:26<00:57, 11.54s/it]
# Translating to ca and back:  97%|█████████▋| 123/127 [22:37<00:46, 11.56s/it]
# Translating to ca and back:  98%|█████████▊| 124/127 [22:50<00:35, 11.76s/it]
# Translating to ca and back:  98%|█████████▊| 125/127 [22:59<00:22, 11.15s/it]
# Translating to ca and back:  99%|█████████▉| 126/127 [23:12<00:11, 11.51s/it]
# Translating to ca and back: 100%|██████████| 127/127 [23:39<00:00, 11.18s/it]
# Processing languages: 100%|██████████| 10/10 [4:45:08<00:00, 1710.89s/it]

# %%
ds=filter_df.to_pandas()
ds.drop(columns=["index","__index_level_0__"],inplace=True)
ds.info()
if torch.cuda.is_available():
    torch.cuda.empty_cache()
ds.sample(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4064 entries, 0 to 4063
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   class                              4064 non-null   object
#  1   comment_sentence                   4064 non-null   object
#  2   partition                          4064 non-null   int64
#  3   combo                              4064 non-null   object
#  4   labels                             4064 non-null   object
#  5   retranslated_text_english_from_de  4064 non-null   object
#  6   retranslated_text_english_from_fr  4064 non-null   object
#  7   retranslated_text_english_from_zh  4064 non-null   object
#  8   retranslated_text_english_from_hi  4064 non-null   object
#  9   retranslated_text_english_from_es  4064 non-null   object
#  10  retranslated_text_english_from_ru  4064 non-null   object
#  11  retranslated_text_english_from_ar  4064 non-null   object
#  12  retranslated_text_english_from_nl  4064 non-null   object
#  13  retranslated_text_english_from_it  4064 non-null   object
#  14  retranslated_text_english_from_ca  4064 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 476.4+ KB
#                   class           comment_sentence  partition  \
# 1121  VScrollTable.java  we have rows rendered and          0
#
#                                               combo                 labels  \
# 1121  we have rows rendered and | VScrollTable.java  [0, 0, 1, 0, 0, 0, 0]
#
#      retranslated_text_english_from_de retranslated_text_english_from_fr  \
# 1121         we have rendered rows and        we have rendered lines and
#
#      retranslated_text_english_from_zh retranslated_text_english_from_hi  \
# 1121                 We're on our own.        And placed a blazing lamp?
#
#      retranslated_text_english_from_es retranslated_text_english_from_ru  \
# 1121         We have rendered rows and              We have set up rows,
#
#      retranslated_text_english_from_ar retranslated_text_english_from_nl  \
# 1121  We have classes like this and...              We've shown rows and
#
#      retranslated_text_english_from_it  \
# 1121           we have rows yields and
#
#             retranslated_text_english_from_ca
# 1121  We have colored rows and processed rows

# %%
# Define the model and tokenizer for sentence encoding
model_name = "sentence-transformers/all-MiniLM-L6-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name).to("cuda" if torch.cuda.is_available() else "cpu")

# List of languages for retranslation analysis

languages = ["de", "fr", "zh", "hi", "es", "ru","ar","nl","it","ca"]

# Function to encode sentences in batches for efficiency
def encode_sentences_in_batches(sentences, batch_size=32):
    """
    Encodes a list of sentences in batches using the pre-trained model.
    Args:
        sentences (list): List of sentences to encode.
        batch_size (int): Size of each batch for encoding.
    Returns:
        torch.Tensor: Tensor containing embeddings for all sentences.
    """
    embeddings = []
    for i in range(0, len(sentences), batch_size):
        batch = sentences[i:i+batch_size]
        # Tokenize and move inputs to the appropriate device (CPU/GPU)
        inputs = tokenizer(batch, padding=True, truncation=True, return_tensors="pt").to("cuda" if torch.cuda.is_available() else "cpu")
        with torch.no_grad():  # Disable gradient computation for inference
            model_output = model(**inputs)
        # Take the mean of the last hidden state to get sentence embeddings
        embeddings.append(model_output.last_hidden_state.mean(dim=1).cpu())
    return torch.cat(embeddings)

# Generate embeddings for original comments
comment_embeddings = encode_sentences_in_batches(ds['comment_sentence'].tolist())

# Set a cosine similarity threshold for filtering translations
threshold = 0.7

# Generate embeddings and filter translations for each language
language_columns = [f"retranslated_text_english_from_{lang}" for lang in languages]
for lang_col in language_columns:
    # Generate embeddings for the retranslated sentences
    retranslated_embeddings = encode_sentences_in_batches(ds[lang_col].fillna("").tolist())
    # Compute cosine similarity between original and retranslated embeddings
    cosine_similarities = torch.nn.functional.cosine_similarity(comment_embeddings, retranslated_embeddings).tolist()
    # Filter translations based on similarity threshold
    filtered_translation_col = f"filtered_{lang_col}"
    ds[filtered_translation_col] = [
        row[lang_col] if similarity > threshold else ""  # Keep translation if similarity exceeds threshold
        for (_, row), similarity in zip(ds.iterrows(), cosine_similarities)
    ]
    
# Prepare for concatenating original and filtered translations
main_columns = ['class', 'comment_sentence', 'labels']  # Main columns to retain in the final dataset
concat_columns = [f"filtered_{lang}" for lang in language_columns]  # Columns containing filtered translations

concat_types = ["de", "fr", "zh", "hi", "es", "ru","ar","nl","it","ca"]

# Create a new DataFrame with original data
df_main = ds[main_columns].copy()
df_main['types'] = 'original'  # Add a column to indicate original comments

# Initialize a list to hold concatenated DataFrames
concat_data = [df_main]

# Add filtered translations to the concatenated DataFrame
for col, col_type in zip(concat_columns, concat_types):
    temp_df = df_main[main_columns].copy()  # Copy main structure
    temp_df['comment_sentence'] = ds[col]  # Replace 'comment_sentence' with filtered translations
    temp_df['types'] = col_type  # Label the type of translation
    concat_data.append(temp_df)  # Append to the list

# Concatenate all DataFrames into one
df_extended = pd.concat(concat_data, ignore_index=True)

#Remove rows with empty or null 'comment_sentence' values
df_extended = df_extended.dropna()  # Drop rows with null values
df_extended = df_extended[df_extended['comment_sentence'] != ""].reset_index(drop=True)  # Drop empty strings
# Display dataset information for debugging or confirmation
df_extended.info()
unfilter_ds["types"]= 'original'
merged_df = pd.concat([unfilter_ds[['class', 'comment_sentence', 'labels', 'types']], 
                       df_extended[['class', 'comment_sentence', 'labels', 'types']]], 
                      ignore_index=True)
merged_df.info()
# Out:
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37285 entries, 0 to 37284
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   class             37285 non-null  object
#  1   comment_sentence  37285 non-null  object
#  2   labels            37285 non-null  object
#  3   types             37285 non-null  object
# dtypes: object(4)
# memory usage: 1.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40835 entries, 0 to 40834
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   class             40835 non-null  object
#  1   comment_sentence  40835 non-null  object
#  2   labels            40835 non-null  object
#  3   types             40835 non-null  object
# dtypes: object(4)
# memory usage: 1.2+ MB

# %%
merged_df.to_csv('java_train.csv', index=False)
